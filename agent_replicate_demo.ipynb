# %%
from sedaro import SedaroApiClient
from pprint import pprint
API_KEY = "PKDqMrtcTK4plJgL7qVlQD.0xQph1lyKzd-pV0-ZL7bRIH7BX54Yjqbz6tluwut3Hvp8XE-RVbfHSz2o5vC77scUhg2xBFuBybplxY6FyXXMQ"
TEMP_AGENT_REPO_BRANCH_ID = "PRkHJlBrpwLDCqPqfbkdrb" # Specific Repo of the Templated agent 
SCENARIO_BRANCH_VERSION_ID = "PRx5rSwrGfkK4n9vFXmVbt" # Version 2
WORKSPACE_ID = "PQtnGZNNPdzZM5JdVhP5P9" # Violet/Ethreal workspace

# %%
# Define modules
sedaro = SedaroApiClient(api_key = API_KEY)
# agent template is only for satellite model (agent), and don't copy the model repo ID, only the branch ID (version)
agent_template_branch = sedaro.agent_template(TEMP_AGENT_REPO_BRANCH_ID) # we are going to change this templated agent

# %%
block_schema = agent_template_branch.data
pprint(block_schema)
# print(block_schema['id'])
# Out:
# {'_abstractBlockTypes': {'ActivePointingMode': False,
#                          'AngleBetweenVectors': False,
#                          'AngularVelocitySensor': False,
#                          'Antenna': False,
#                          'AreaTarget': False,
#                          'AveragingAlgorithm': False,
#                          'BatteryCell': False,
#                          'BatteryPack': False,
#                          'BmskBodyMask': False,
#                          'BodyFrameVector': False,
#                          'BodyMask': False,
#                          'BusRegulator': False,
#                          'CelestialTarget': False,
#                          'CelestialVector': False,
#                          'CircularFieldOfView': False,
#                          'Clock': False,
#                          'CombinationalLogic': False,
#                          'Component': False,
#                          'ComponentToScalarCondition': False,
#                          'CompoundCondition': False,
#                          'ConductiveThermalInterface': False,
#                          'Cooler': False,
#                          'DataBus': False,
#                          'DataInterfaceToScalarCondition': False,
#                          'DataMode': False,
#                          'DataProtocol': False,
#                          'DataStorage': False,
#                          'DataType': False,
#                          'DirectDriveAlgorithm': False,
#                          'DirectMeasurementAttitudeInitializer': False,
#                          'DirectionSensor': False,
#                          'DockingPort': False,
#                          'DynamicallyLoadedComponent': True,
#                          'EkfAlgorithm': False,
#                          'ElapsedTimeCondition': False,
#                          'ExperimentalCondition': False,
#                          'FieldOfViewArticulationMode': False,
#                          'FiniteDifferenceOrbitInitializer': False,
#                          'FiniteStateMachine': False,
#                          'FixedSchedule': False,
#                          'FixedSurface': False,
#                          'FixedThrustRelativeManeuverAlgorithm': False,
#                          'FixedTimeHcwTransferAlgorithm': False,
#                          'FuelReservoir': False,
#                          'FuelingPort': False,
#                          'FullNetworkDataModel': False,
#                          'FullyRegDetPowerProcessor': False,
#                          'GenericAdAlgorithm': False,
#                          'GenericOdAlgorithm': False,
#                          'GenericOpticalAttitudeSensor': False,
#                          'GenericPositionSensor': False,
#                          'GenericRelativeAttitudeDeterminationAlgorithm': False,
#                          'GenericRelativeOrbitDeterminationAlgorithm': False,
#                          'GenericTemperatureSensor': False,
#                          'GnssReceiver': False,
#                          'GpsAlgorithm': False,
#                          'GroundSegmentTarget': False,
#                          'GroundTarget': False,
#                          'Heater': False,
#                          'IdealOrbitalAttitudeDynamics': False,
#                          'ImpulsiveDeltaVAlgorithm': False,
#                          'ImpulsiveRelativeManeuverAlgorithm': False,
#                          'InstantVelocitySetpointActuationMode': False,
#                          'InternalDataInterface': False,
#                          'InterpolatedGainPattern': False,
#                          'LaserCommModule': False,
#                          'LineOfSightReceiveInterface': False,
#                          'LineOfSightTransmitInterface': False,
#                          'LoadState': False,
#                          'LocalVector': False,
#                          'LockSpinPointingMode': False,
#                          'LogicalConfiguration': False,
#                          'MagneticDetumblingAlgorithm': False,
#                          'MagneticHysteresisRod': False,
#                          'Magnetorquer': False,
#                          'ManipulatedSurface': False,
#                          'ManipulatorAssembly': False,
#                          'MasslessPrismaticManipulatorSegment': False,
#                          'MasslessRevoluteManipulatorSegment': False,
#                          'MaxAlignPointingMode': False,
#                          'MekfAlgorithm': False,
#                          'MemsAngularVelocitySensor': False,
#                          'Modem': False,
#                          'OpticsPayload': False,
#                          'OrbitalAttitudeDynamics': False,
#                          'OrientedFiducial': False,
#                          'ParallelPackBattery': False,
#                          'PassivePointingMode': False,
#                          'PathLossConfig': False,
#                          'PermanentDipoleMagnet': False,
#                          'PhotovoltaicPowerProcessor': False,
#                          'PidAlgorithm': False,
#                          'PointFiducial': False,
#                          'PositionSensor': True,
#                          'PowerLoad': False,
#                          'PowerProcessor': False,
#                          'PriorKnowledgeRelativeOrbitInitializer': False,
#                          'ProjectedVector': False,
#                          'PropagatedOrbitKinematics': False,
#                          'QuasiRegDetPowerProcessor': False,
#                          'RadiativeThermalInterface': False,
#                          'ReactionWheel': False,
#                          'RectangularFieldOfView': False,
#                          'RectangularFixedSurface': False,
#                          'RectangularSunTrackingSurface': False,
#                          'RectangularVectorTrackingSurface': False,
#                          'RelativeAttitudeMekfAlgorithm': False,
#                          'RelativeOrbitEkfAlgorithm': False,
#                          'RelativeSchedule': False,
#                          'ResistanceLoad': False,
#                          'Routine': False,
#                          'SameTargetMultiCondition': False,
#                          'SatelliteToSatelliteCondition': False,
#                          'SatelliteToScalarCondition': False,
#                          'SatelliteToTargetCondition': False,
#                          'ScanFieldOfViewArticulationMode': False,
#                          'Sensor': True,
#                          'SensorFailureMode': True,
#                          'SeriesPackBattery': False,
#                          'SingleConvHybridPowerProcessor': False,
#                          'SingleConvMpptPowerProcessor': False,
#                          'SlidingModeAlgorithm': False,
#                          'SolarArray': False,
#                          'SolarCell': False,
#                          'SolarPanel': False,
#                          'SpaceTarget': False,
#                          'SpacecraftPowerModel': False,
#                          'SphericalFuelTank': False,
#                          'SpherocylinderFuelTank': False,
#                          'SpkEphemeris': False,
#                          'StarTracker': False,
#                          'StateTransition': False,
#                          'StaticAttitudeInitializer': False,
#                          'StaticFieldOfViewArticulationMode': False,
#                          'StaticRelativeAttitudeInitializer': False,
#                          'StaticThrustControlAlgorithm': False,
#                          'StkEphemeris': False,
#                          'StkGainPattern': False,
#                          'Subsystem': False,
#                          'SunTrackingSurface': False,
#                          'SurfaceMaterial': False,
#                          'TargetAttitudeSensor': False,
#                          'TargetFiducialAngleToScalarCondition': False,
#                          'TargetFiducialSensor': False,
#                          'TargetGroup': False,
#                          'TargetGroupInFovCondition': False,
#                          'TargetGroupToSatelliteCondition': False,
#                          'TargetGroupToScalarCondition': False,
#                          'TargetGroupToTargetCondition': False,
#                          'TargetGroupVector': False,
#                          'TargetInFovCondition': False,
#                          'TargetLidarSensor': False,
#                          'TargetPositionSensor': False,
#                          'TargetRadarSensor': False,
#                          'TargetRangeRateSensor': False,
#                          'TargetRangeSensor': False,
#                          'TargetToScalarCondition': False,
#                          'TargetToTargetCondition': False,
#                          'TargetVector': False,
#                          'TempControllerState': False,
#                          'ThermalCircuitModel': False,
#                          'ThermalDesignLayout': False,
#                          'ThermalInterfaceMaterial': False,
#                          'Thruster': False,
#                          'ThrusterGroup': False,
#                          'TimeCondition': False,
#                          'TimeStepMode': False,
#                          'TrackingFieldOfViewArticulationMode': False,
#                          'TriadAlgorithm': False,
#                          'TriadAttitudeInitializer': False,
#                          'TwoConvMpptPowerProcessor': False,
#                          'UkfAlgorithm': False,
#                          'UnresponsiveMagnetorquerFailureMode': False,
#                          'UnresponsiveReactionWheelFailureMode': False,
#                          'UnresponsiveSensorFailureMode': False,
#                          'UnresponsiveThrusterFailureMode': False,
#                          'VariableThrustRelativeManeuverAlgorithm': False,
#                          'VectorInFovCondition': False,
#                          'VectorSensor': False,
#                          'VectorTrackingSurface': False,
#                          'root': False},
#  '_blockNames': ['ActivePointingMode',
#                  'AngleBetweenVectors',
#                  'AngularVelocitySensor',
#                  'Antenna',
#                  'AreaTarget',
#                  'AveragingAlgorithm',
#                  'BatteryCell',
#                  'BatteryPack',
#                  'BmskBodyMask',
#                  'BodyFrameVector',
#                  'BodyMask',
#                  'BusRegulator',
#                  'CelestialTarget',
#                  'CelestialVector',
#                  'CircularFieldOfView',
#                  'Clock',
#                  'CombinationalLogic',
#                  'Component',
#                  'ComponentToScalarCondition',
#                  'CompoundCondition',
#                  'ConductiveThermalInterface',
#                  'Cooler',
#                  'DataBus',
#                  'DataInterfaceToScalarCondition',
#                  'DataMode',
#                  'DataProtocol',
#                  'DataStorage',
#                  'DataType',
#                  'DirectDriveAlgorithm',
#                  'DirectMeasurementAttitudeInitializer',
#                  'DirectionSensor',
#                  'DockingPort',
#                  'DynamicallyLoadedComponent',
#                  'EkfAlgorithm',
#                  'ElapsedTimeCondition',
#                  'ExperimentalCondition',
#                  'FieldOfViewArticulationMode',
#                  'FiniteDifferenceOrbitInitializer',
#                  'FiniteStateMachine',
#                  'FixedSchedule',
#                  'FixedSurface',
#                  'FixedThrustRelativeManeuverAlgorithm',
#                  'FixedTimeHcwTransferAlgorithm',
#                  'FuelReservoir',
#                  'FuelingPort',
#                  'FullNetworkDataModel',
#                  'FullyRegDetPowerProcessor',
#                  'GenericAdAlgorithm',
#                  'GenericOdAlgorithm',
#                  'GenericOpticalAttitudeSensor',
#                  'GenericPositionSensor',
#                  'GenericRelativeAttitudeDeterminationAlgorithm',
#                  'GenericRelativeOrbitDeterminationAlgorithm',
#                  'GenericTemperatureSensor',
#                  'GnssReceiver',
#                  'GpsAlgorithm',
#                  'GroundSegmentTarget',
#                  'GroundTarget',
#                  'Heater',
#                  'IdealOrbitalAttitudeDynamics',
#                  'ImpulsiveDeltaVAlgorithm',
#                  'ImpulsiveRelativeManeuverAlgorithm',
#                  'InstantVelocitySetpointActuationMode',
#                  'InternalDataInterface',
#                  'InterpolatedGainPattern',
#                  'LaserCommModule',
#                  'LineOfSightReceiveInterface',
#                  'LineOfSightTransmitInterface',
#                  'LoadState',
#                  'LocalVector',
#                  'LockSpinPointingMode',
#                  'LogicalConfiguration',
#                  'MagneticDetumblingAlgorithm',
#                  'MagneticHysteresisRod',
#                  'Magnetorquer',
#                  'ManipulatedSurface',
#                  'ManipulatorAssembly',
#                  'MasslessPrismaticManipulatorSegment',
#                  'MasslessRevoluteManipulatorSegment',
#                  'MaxAlignPointingMode',
#                  'MekfAlgorithm',
#                  'MemsAngularVelocitySensor',
#                  'Modem',
#                  'OpticsPayload',
#                  'OrbitalAttitudeDynamics',
#                  'OrientedFiducial',
#                  'ParallelPackBattery',
#                  'PassivePointingMode',
#                  'PathLossConfig',
#                  'PermanentDipoleMagnet',
#                  'PhotovoltaicPowerProcessor',
#                  'PidAlgorithm',
#                  'PointFiducial',
#                  'PositionSensor',
#                  'PowerLoad',
#                  'PowerProcessor',
#                  'PriorKnowledgeRelativeOrbitInitializer',
#                  'ProjectedVector',
#                  'PropagatedOrbitKinematics',
#                  'QuasiRegDetPowerProcessor',
#                  'RadiativeThermalInterface',
#                  'ReactionWheel',
#                  'RectangularFieldOfView',
#                  'RectangularFixedSurface',
#                  'RectangularSunTrackingSurface',
#                  'RectangularVectorTrackingSurface',
#                  'RelativeAttitudeMekfAlgorithm',
#                  'RelativeOrbitEkfAlgorithm',
#                  'RelativeSchedule',
#                  'ResistanceLoad',
#                  'Routine',
#                  'SameTargetMultiCondition',
#                  'SatelliteToSatelliteCondition',
#                  'SatelliteToScalarCondition',
#                  'SatelliteToTargetCondition',
#                  'ScanFieldOfViewArticulationMode',
#                  'Sensor',
#                  'SensorFailureMode',
#                  'SeriesPackBattery',
#                  'SingleConvHybridPowerProcessor',
#                  'SingleConvMpptPowerProcessor',
#                  'SlidingModeAlgorithm',
#                  'SolarArray',
#                  'SolarCell',
#                  'SolarPanel',
#                  'SpaceTarget',
#                  'SpacecraftPowerModel',
#                  'SphericalFuelTank',
#                  'SpherocylinderFuelTank',
#                  'SpkEphemeris',
#                  'StarTracker',
#                  'StateTransition',
#                  'StaticAttitudeInitializer',
#                  'StaticFieldOfViewArticulationMode',
#                  'StaticRelativeAttitudeInitializer',
#                  'StaticThrustControlAlgorithm',
#                  'StkEphemeris',
#                  'StkGainPattern',
#                  'Subsystem',
#                  'SunTrackingSurface',
#                  'SurfaceMaterial',
#                  'TargetAttitudeSensor',
#                  'TargetFiducialAngleToScalarCondition',
#                  'TargetFiducialSensor',
#                  'TargetGroup',
#                  'TargetGroupInFovCondition',
#                  'TargetGroupToSatelliteCondition',
#                  'TargetGroupToScalarCondition',
#                  'TargetGroupToTargetCondition',
#                  'TargetGroupVector',
#                  'TargetInFovCondition',
#                  'TargetLidarSensor',
#                  'TargetPositionSensor',
#                  'TargetRadarSensor',
#                  'TargetRangeRateSensor',
#                  'TargetRangeSensor',
#                  'TargetToScalarCondition',
#                  'TargetToTargetCondition',
#                  'TargetVector',
#                  'TempControllerState',
#                  'ThermalCircuitModel',
#                  'ThermalDesignLayout',
#                  'ThermalInterfaceMaterial',
#                  'Thruster',
#                  'ThrusterGroup',
#                  'TimeCondition',
#                  'TimeStepMode',
#                  'TrackingFieldOfViewArticulationMode',
#                  'TriadAlgorithm',
#                  'TriadAttitudeInitializer',
#                  'TwoConvMpptPowerProcessor',
#                  'UkfAlgorithm',
#                  'UnresponsiveMagnetorquerFailureMode',
#                  'UnresponsiveReactionWheelFailureMode',
#                  'UnresponsiveSensorFailureMode',
#                  'UnresponsiveThrusterFailureMode',
#                  'VariableThrustRelativeManeuverAlgorithm',
#                  'VectorInFovCondition',
#                  'VectorSensor',
#                  'VectorTrackingSurface'],
#  '_quantityKinds': {'ActivePointingMode': {},
#                     'Actuator': {'coldMargin': {'baseName': 'Temperature',
#                                                 'defaultUnit': 'degK',
#                                                 'name': 'Temperature'},
#                                  'coldTempRating': {'baseName': 'Temperature',
#                                                     'defaultUnit': 'degK',
#                                                     'name': 'Temperature'},
#                                  'hotMargin': {'baseName': 'Temperature',
#                                                'defaultUnit': 'degK',
#                                                'name': 'Temperature'},
#                                  'hotTempRating': {'baseName': 'Temperature',
#                                                    'defaultUnit': 'degK',
#                                                    'name': 'Temperature'},
#                                  'temperature': {'baseName': 'Temperature',
#                                                  'defaultUnit': 'degK',
#                                                  'name': 'Temperature'}},
#                     'ActuatorFailureMode': {},
#                     'Algorithm': {},
#                     'AngleBetweenVectors': {},
#                     'AngularVelocitySensor': {'coldMargin': {'baseName': 'Temperature',
#                                                              'defaultUnit': 'degK',
#                                                              'name': 'Temperature'},
#                                               'coldTempRating': {'baseName': 'Temperature',
#                                                                  'defaultUnit': 'degK',
#                                                                  'name': 'Temperature'},
#                                               'hotMargin': {'baseName': 'Temperature',
#                                                             'defaultUnit': 'degK',
#                                                             'name': 'Temperature'},
#                                               'hotTempRating': {'baseName': 'Temperature',
#                                                                 'defaultUnit': 'degK',
#                                                                 'name': 'Temperature'},
#                                               'oneSigmaPerAxisError': {'baseName': 'AngularRate',
#                                                                        'defaultUnit': 'rad/s',
#                                                                        'name': 'NonNegativeAngularRate'},
#                                               'sensorAttitude': {'baseName': 'Quaternion',
#                                                                  'defaultUnit': 'body_eci',
#                                                                  'name': 'Quaternion'},
#                                               'sensorPosition': {'baseName': 'Position',
#                                                                  'defaultUnit': 'eci',
#                                                                  'name': 'Position'},
#                                               'temperature': {'baseName': 'Temperature',
#                                                               'defaultUnit': 'degK',
#                                                               'name': 'Temperature'},
#                                               'timeSinceMeasurement': {'baseName': 'Duration',
#                                                                        'defaultUnit': 'day',
#                                                                        'name': 'NonNegativeDuration'},
#                                               'updateInterval': {'baseName': 'Duration',
#                                                                  'defaultUnit': 'day',
#                                                                  'name': 'PositiveDuration'}},
#                     'Antenna': {'coldMargin': {'baseName': 'Temperature',
#                                                'defaultUnit': 'degK',
#                                                'name': 'Temperature'},
#                                 'coldTempRating': {'baseName': 'Temperature',
#                                                    'defaultUnit': 'degK',
#                                                    'name': 'Temperature'},
#                                 'hotMargin': {'baseName': 'Temperature',
#                                               'defaultUnit': 'degK',
#                                               'name': 'Temperature'},
#                                 'hotTempRating': {'baseName': 'Temperature',
#                                                   'defaultUnit': 'degK',
#                                                   'name': 'Temperature'},
#                                 'polarizationTiltAngle': {'baseName': 'Angle',
#                                                           'defaultUnit': 'rad',
#                                                           'name': 'FirstQuadrantAngle'},
#                                 'rxWavelength': {'baseName': 'Distance',
#                                                  'defaultUnit': 'km',
#                                                  'name': 'PositiveDistance'},
#                                 'temperature': {'baseName': 'Temperature',
#                                                 'defaultUnit': 'degK',
#                                                 'name': 'Temperature'},
#                                 'txWavelength': {'baseName': 'Distance',
#                                                  'defaultUnit': 'km',
#                                                  'name': 'PositiveDistance'}},
#                     'AreaTarget': {'alt': {'baseName': 'Distance',
#                                            'defaultUnit': 'km',
#                                            'name': 'Distance'},
#                                    'lat': {'baseName': 'Angle',
#                                            'defaultUnit': 'rad',
#                                            'name': 'Angle'},
#                                    'lon': {'baseName': 'Angle',
#                                            'defaultUnit': 'rad',
#                                            'name': 'Angle'},
#                                    'position': {'baseName': 'Position',
#                                                 'defaultUnit': 'eci',
#                                                 'name': 'Position'},
#                                    'range': {'baseName': 'Distance',
#                                              'defaultUnit': 'km',
#                                              'name': 'NonNegativeDistance'},
#                                    'rangeRate': {'baseName': 'Speed',
#                                                  'defaultUnit': 'km/s',
#                                                  'name': 'Speed'},
#                                    'relativePosition': {'baseName': 'FrameVector',
#                                                         'defaultUnit': 'eci',
#                                                         'name': 'FrameVector'},
#                                    'targetAzimuth': {'baseName': 'Angle',
#                                                      'defaultUnit': 'rad',
#                                                      'name': 'Angle'},
#                                    'targetElevation': {'baseName': 'Angle',
#                                                        'defaultUnit': 'rad',
#                                                        'name': 'Angle'}},
#                     'AttitudeControlAlgorithm': {'timeSinceUpdate': {'baseName': 'Duration',
#                                                                      'defaultUnit': 'day',
#                                                                      'name': 'PositiveDuration'}},
#                     'AttitudeDeterminationAlgorithm': {},
#                     'AttitudeDynamics': {},
#                     'AttitudeInitializer': {},
#                     'AttitudeSensor': {'bodyFrameMeasurement': {'baseName': 'Quaternion',
#                                                                 'defaultUnit': 'body_eci',
#                                                                 'name': 'Quaternion'},
#                                        'coldMargin': {'baseName': 'Temperature',
#                                                       'defaultUnit': 'degK',
#                                                       'name': 'Temperature'},
#                                        'coldTempRating': {'baseName': 'Temperature',
#                                                           'defaultUnit': 'degK',
#                                                           'name': 'Temperature'},
#                                        'hotMargin': {'baseName': 'Temperature',
#                                                      'defaultUnit': 'degK',
#                                                      'name': 'Temperature'},
#                                        'hotTempRating': {'baseName': 'Temperature',
#                                                          'defaultUnit': 'degK',
#                                                          'name': 'Temperature'},
#                                        'measurement': {'baseName': 'Quaternion',
#                                                        'defaultUnit': 'body_eci',
#                                                        'name': 'Quaternion'},
#                                        'sensorAttitude': {'baseName': 'Quaternion',
#                                                           'defaultUnit': 'body_eci',
#                                                           'name': 'Quaternion'},
#                                        'sensorPosition': {'baseName': 'Position',
#                                                           'defaultUnit': 'eci',
#                                                           'name': 'Position'},
#                                        'temperature': {'baseName': 'Temperature',
#                                                        'defaultUnit': 'degK',
#                                                        'name': 'Temperature'},
#                                        'timeSinceMeasurement': {'baseName': 'Duration',
#                                                                 'defaultUnit': 'day',
#                                                                 'name': 'NonNegativeDuration'},
#                                        'truth': {'baseName': 'Quaternion',
#                                                  'defaultUnit': 'body_eci',
#                                                  'name': 'Quaternion'},
#                                        'updateInterval': {'baseName': 'Duration',
#                                                           'defaultUnit': 'day',
#                                                           'name': 'PositiveDuration'}},
#                     'AveragingAlgorithm': {},
#                     'Battery': {},
#                     'BatteryCell': {},
#                     'BatteryPack': {'coldMargin': {'baseName': 'Temperature',
#                                                    'defaultUnit': 'degK',
#                                                    'name': 'Temperature'},
#                                     'coldTempRating': {'baseName': 'Temperature',
#                                                        'defaultUnit': 'degK',
#                                                        'name': 'Temperature'},
#                                     'hotMargin': {'baseName': 'Temperature',
#                                                   'defaultUnit': 'degK',
#                                                   'name': 'Temperature'},
#                                     'hotTempRating': {'baseName': 'Temperature',
#                                                       'defaultUnit': 'degK',
#                                                       'name': 'Temperature'},
#                                     'temperature': {'baseName': 'Temperature',
#                                                     'defaultUnit': 'degK',
#                                                     'name': 'Temperature'}},
#                     'BlockWithQuantityKind': {},
#                     'BmskBodyMask': {},
#                     'BodyFrameVector': {},
#                     'BodyMask': {},
#                     'BusRegulator': {},
#                     'CelestialTarget': {'alt': {'baseName': 'Distance',
#                                                 'defaultUnit': 'km',
#                                                 'name': 'Distance'},
#                                         'lat': {'baseName': 'Angle',
#                                                 'defaultUnit': 'rad',
#                                                 'name': 'Angle'},
#                                         'lon': {'baseName': 'Angle',
#                                                 'defaultUnit': 'rad',
#                                                 'name': 'Angle'},
#                                         'position': {'baseName': 'Position',
#                                                      'defaultUnit': 'eci',
#                                                      'name': 'Position'},
#                                         'range': {'baseName': 'Distance',
#                                                   'defaultUnit': 'km',
#                                                   'name': 'NonNegativeDistance'},
#                                         'rangeRate': {'baseName': 'Speed',
#                                                       'defaultUnit': 'km/s',
#                                                       'name': 'Speed'},
#                                         'relativePosition': {'baseName': 'FrameVector',
#                                                              'defaultUnit': 'eci',
#                                                              'name': 'FrameVector'},
#                                         'targetAzimuth': {'baseName': 'Angle',
#                                                           'defaultUnit': 'rad',
#                                                           'name': 'Angle'},
#                                         'targetElevation': {'baseName': 'Angle',
#                                                             'defaultUnit': 'rad',
#                                                             'name': 'Angle'}},
#                     'CelestialVector': {'estimate': {'baseName': 'FrameVector',
#                                                      'defaultUnit': 'eci',
#                                                      'name': 'FrameVector'},
#                                         'truth': {'baseName': 'FrameVector',
#                                                   'defaultUnit': 'eci',
#                                                   'name': 'FrameVector'}},
#                     'CircularFieldOfView': {'articulations': {'maxSlewRate': {'baseName': 'AngularRate',
#                                                                               'defaultUnit': 'rad/s',
#                                                                               'name': 'PositiveAngularRate'},
#                                                               'negativeAngleLimit': {'baseName': 'Angle',
#                                                                                      'defaultUnit': 'rad',
#                                                                                      'name': 'AnyQuadrantAngle'},
#                                                               'positiveAngleLimit': {'baseName': 'Angle',
#                                                                                      'defaultUnit': 'rad',
#                                                                                      'name': 'AnyQuadrantAngle'}},
#                                             'attitude': {'baseName': 'Quaternion',
#                                                          'defaultUnit': 'body_eci',
#                                                          'name': 'Quaternion'},
#                                             'halfAngle': {'baseName': 'Angle',
#                                                           'defaultUnit': 'rad',
#                                                           'name': 'UpperQuadrantAngle'}},
#                     'Clock': {'clockError': {'baseName': 'Duration',
#                                              'defaultUnit': 'day',
#                                              'name': 'Duration'},
#                               'coldMargin': {'baseName': 'Temperature',
#                                              'defaultUnit': 'degK',
#                                              'name': 'Temperature'},
#                               'coldTempRating': {'baseName': 'Temperature',
#                                                  'defaultUnit': 'degK',
#                                                  'name': 'Temperature'},
#                               'cumulativeError': {'baseName': 'Duration',
#                                                   'defaultUnit': 'day',
#                                                   'name': 'NonNegativeDuration'},
#                               'hotMargin': {'baseName': 'Temperature',
#                                             'defaultUnit': 'degK',
#                                             'name': 'Temperature'},
#                               'hotTempRating': {'baseName': 'Temperature',
#                                                 'defaultUnit': 'degK',
#                                                 'name': 'Temperature'},
#                               'temperature': {'baseName': 'Temperature',
#                                               'defaultUnit': 'degK',
#                                               'name': 'Temperature'}},
#                     'CombinationalLogic': {'timeSinceActive': {'baseName': 'Duration',
#                                                                'defaultUnit': 'day',
#                                                                'name': 'NonNegativeDuration'},
#                                            'timeSinceInactive': {'baseName': 'Duration',
#                                                                  'defaultUnit': 'day',
#                                                                  'name': 'NonNegativeDuration'}},
#                     'CompareCondition': {},
#                     'Component': {'coldMargin': {'baseName': 'Temperature',
#                                                  'defaultUnit': 'degK',
#                                                  'name': 'Temperature'},
#                                   'coldTempRating': {'baseName': 'Temperature',
#                                                      'defaultUnit': 'degK',
#                                                      'name': 'Temperature'},
#                                   'hotMargin': {'baseName': 'Temperature',
#                                                 'defaultUnit': 'degK',
#                                                 'name': 'Temperature'},
#                                   'hotTempRating': {'baseName': 'Temperature',
#                                                     'defaultUnit': 'degK',
#                                                     'name': 'Temperature'},
#                                   'temperature': {'baseName': 'Temperature',
#                                                   'defaultUnit': 'degK',
#                                                   'name': 'Temperature'}},
#                     'ComponentToScalarCondition': {},
#                     'CompoundCondition': {},
#                     'Condition': {},
#                     'ConductiveThermalInterface': {'coldMargin': {'baseName': 'Temperature',
#                                                                   'defaultUnit': 'degK',
#                                                                   'name': 'Temperature'},
#                                                    'coldTemp': {'baseName': 'Temperature',
#                                                                 'defaultUnit': 'degK',
#                                                                 'name': 'Temperature'},
#                                                    'hotMargin': {'baseName': 'Temperature',
#                                                                  'defaultUnit': 'degK',
#                                                                  'name': 'Temperature'},
#                                                    'hotTemp': {'baseName': 'Temperature',
#                                                                'defaultUnit': 'degK',
#                                                                'name': 'Temperature'},
#                                                    'thickness': {'baseName': 'Distance',
#                                                                  'defaultUnit': 'km',
#                                                                  'name': 'PositiveDistance'}},
#                     'ConstantLoad': {'dutyCyclePeriod': {'baseName': 'Duration',
#                                                          'defaultUnit': 'day',
#                                                          'name': 'NonNegativeDuration'}},
#                     'Cooler': {'coldMargin': {'baseName': 'Temperature',
#                                               'defaultUnit': 'degK',
#                                               'name': 'Temperature'},
#                                'coldTempRating': {'baseName': 'Temperature',
#                                                   'defaultUnit': 'degK',
#                                                   'name': 'Temperature'},
#                                'commandedTemperature': {'baseName': 'Temperature',
#                                                         'defaultUnit': 'degK',
#                                                         'name': 'Temperature'},
#                                'hotMargin': {'baseName': 'Temperature',
#                                              'defaultUnit': 'degK',
#                                              'name': 'Temperature'},
#                                'hotTempRating': {'baseName': 'Temperature',
#                                                  'defaultUnit': 'degK',
#                                                  'name': 'Temperature'},
#                                'temperature': {'baseName': 'Temperature',
#                                                'defaultUnit': 'degK',
#                                                'name': 'Temperature'}},
#                     'DataBus': {},
#                     'DataInterface': {},
#                     'DataInterfaceToScalarCondition': {},
#                     'DataMode': {},
#                     'DataModel': {},
#                     'DataProtocol': {},
#                     'DataStorage': {},
#                     'DataType': {},
#                     'DesignLayout': {},
#                     'DirectDriveAlgorithm': {'timeSinceUpdate': {'baseName': 'Duration',
#                                                                  'defaultUnit': 'day',
#                                                                  'name': 'PositiveDuration'}},
#                     'DirectMeasurementAttitudeInitializer': {'angularVelocitySensors': {'angularVelocityBias': {'baseName': 'AngularVelocity',
#                                                                                                                 'defaultUnit': 'rad/s',
#                                                                                                                 'name': 'AngularVelocity'},
#                                                                                         'oneSigmaAngularVelocityError': {'baseName': 'AngularRate',
#                                                                                                                          'defaultUnit': 'rad/s',
#                                                                                                                          'name': 'PositiveAngularRate'},
#                                                                                         'oneSigmaBiasError': {'baseName': 'AngularRate',
#                                                                                                               'defaultUnit': 'rad/s',
#                                                                                                               'name': 'PositiveAngularRate'}},
#                                                              'attitudeSensors': {'oneSigmaAngleError': {'baseName': 'Angle',
#                                                                                                         'defaultUnit': 'rad',
#                                                                                                         'name': 'PositiveFirstQuadrantAngle'}},
#                                                              'defaultAngularVelocitySigma': {'baseName': 'AngularRate',
#                                                                                              'defaultUnit': 'rad/s',
#                                                                                              'name': 'PositiveAngularRate'}},
#                     'DirectTorqueActuator': {'coldMargin': {'baseName': 'Temperature',
#                                                             'defaultUnit': 'degK',
#                                                             'name': 'Temperature'},
#                                              'coldTempRating': {'baseName': 'Temperature',
#                                                                 'defaultUnit': 'degK',
#                                                                 'name': 'Temperature'},
#                                              'hotMargin': {'baseName': 'Temperature',
#                                                            'defaultUnit': 'degK',
#                                                            'name': 'Temperature'},
#                                              'hotTempRating': {'baseName': 'Temperature',
#                                                                'defaultUnit': 'degK',
#                                                                'name': 'Temperature'},
#                                              'temperature': {'baseName': 'Temperature',
#                                                              'defaultUnit': 'degK',
#                                                              'name': 'Temperature'}},
#                     'DirectedEnergyDevice': {'coldMargin': {'baseName': 'Temperature',
#                                                             'defaultUnit': 'degK',
#                                                             'name': 'Temperature'},
#                                              'coldTempRating': {'baseName': 'Temperature',
#                                                                 'defaultUnit': 'degK',
#                                                                 'name': 'Temperature'},
#                                              'hotMargin': {'baseName': 'Temperature',
#                                                            'defaultUnit': 'degK',
#                                                            'name': 'Temperature'},
#                                              'hotTempRating': {'baseName': 'Temperature',
#                                                                'defaultUnit': 'degK',
#                                                                'name': 'Temperature'},
#                                              'polarizationTiltAngle': {'baseName': 'Angle',
#                                                                        'defaultUnit': 'rad',
#                                                                        'name': 'FirstQuadrantAngle'},
#                                              'temperature': {'baseName': 'Temperature',
#                                                              'defaultUnit': 'degK',
#                                                              'name': 'Temperature'}},
#                     'DirectionSensor': {'coldMargin': {'baseName': 'Temperature',
#                                                        'defaultUnit': 'degK',
#                                                        'name': 'Temperature'},
#                                         'coldTempRating': {'baseName': 'Temperature',
#                                                            'defaultUnit': 'degK',
#                                                            'name': 'Temperature'},
#                                         'hotMargin': {'baseName': 'Temperature',
#                                                       'defaultUnit': 'degK',
#                                                       'name': 'Temperature'},
#                                         'hotTempRating': {'baseName': 'Temperature',
#                                                           'defaultUnit': 'degK',
#                                                           'name': 'Temperature'},
#                                         'oneSigmaAngleError': {'baseName': 'Angle',
#                                                                'defaultUnit': 'rad',
#                                                                'name': 'NonNegativeAngle'},
#                                         'sensorAttitude': {'baseName': 'Quaternion',
#                                                            'defaultUnit': 'body_eci',
#                                                            'name': 'Quaternion'},
#                                         'sensorPosition': {'baseName': 'Position',
#                                                            'defaultUnit': 'eci',
#                                                            'name': 'Position'},
#                                         'temperature': {'baseName': 'Temperature',
#                                                         'defaultUnit': 'degK',
#                                                         'name': 'Temperature'},
#                                         'timeSinceMeasurement': {'baseName': 'Duration',
#                                                                  'defaultUnit': 'day',
#                                                                  'name': 'NonNegativeDuration'},
# ...
#                                                  'type "Subsystem" in field '
#                                                  '"name": "Command & '
#                                                  'Control".'],
#                        'NSgheitRQ51bMoH_95sZk': ['Subsystem(name="Data '
#                                                  'Handling" '
#                                                  'id=NSgheitRQ51bMoH_95sZk) is '
#                                                  'violating a unique '
#                                                  'constraint for Blocks of '
#                                                  'type "Subsystem" in field '
#                                                  '"name": "Data Handling".'],
#                        'NSghgp0ThH8gNv5Ady03k': ['Subsystem(name="GNC" '
#                                                  'id=NSghgp0ThH8gNv5Ady03k) is '
#                                                  'violating a unique '
#                                                  'constraint for Blocks of '
#                                                  'type "Subsystem" in field '
#                                                  '"name": "GNC".'],
#                        'NSghj1hTM9mz2Vl08G5rk': ['Subsystem(name="Thermal" '
#                                                  'id=NSghj1hTM9mz2Vl08G5rk) is '
#                                                  'violating a unique '
#                                                  'constraint for Blocks of '
#                                                  'type "Subsystem" in field '
#                                                  '"name": "Thermal".'],
#                        'NSghkyoTLeQzaNfeeckQV': ['Subsystem(name="Structure" '
#                                                  'id=NSghkyoTLeQzaNfeeckQV) is '
#                                                  'violating a unique '
#                                                  'constraint for Blocks of '
#                                                  'type "Subsystem" in field '
#                                                  '"name": "Structure".'],
#                        'PRkngd9JJDFBskzmrzbhfm': ['External data interface '
#                                                   '"Downlink" must have '
#                                                   'exactly one static target '
#                                                   'or one target group '
#                                                   'assigned, but not both.'],
#                        'PRknqNmldqNZvff74HWZkc': ['A value for "targetA" is '
#                                                   'required on '
#                                                   'TargetToScalarCondition(name="Target '
#                                                   'LoS" '
#                                                   'id=PRknqNmldqNZvff74HWZkc).',
#                                                   'The relationship `targetA` '
#                                                   'on '
#                                                   'TargetToScalarCondition(name="Target '
#                                                   'LoS" '
#                                                   'id=PRknqNmldqNZvff74HWZkc) '
#                                                   'is undefined which is '
#                                                   'preventing validation. '
#                                                   'Please fully define the '
#                                                   'model to validate it.'],
#                        'PRkntw3tVlwzbxBkQgXw8V': ['A value for '
#                                                   '"referenceTarget" is '
#                                                   'required on '
#                                                   'TargetVector(name="Ground '
#                                                   'Target Placeholder - Target '
#                                                   'Truth (6Xm1bwj)" '
#                                                   'id=PRkntw3tVlwzbxBkQgXw8V).'],
#                        'PRwzP4dbw3VpMmHmVcKq2N': ['A value for '
#                                                   '"referenceTarget" is '
#                                                   'required on '
#                                                   'TargetVector(name="Sat '
#                                                   'target - Target Truth '
#                                                   '(pnkkJZj)" '
#                                                   'id=PRwzP4dbw3VpMmHmVcKq2N).'],
#                        'PRwzRZgLJrlx9bDnf5YW4t': ['A value for "targetA" is '
#                                                   'required on '
#                                                   'TargetToScalarCondition(name="Sat '
#                                                   'LoS" '
#                                                   'id=PRwzRZgLJrlx9bDnf5YW4t).',
#                                                   'The relationship `targetA` '
#                                                   'on '
#                                                   'TargetToScalarCondition(name="Sat '
#                                                   'LoS" '
#                                                   'id=PRwzRZgLJrlx9bDnf5YW4t) '
#                                                   'is undefined which is '
#                                                   'preventing validation. '
#                                                   'Please fully define the '
#                                                   'model to validate it.'],
#                        'PS2NjSRL2J9q6tpD5HllPs': ['Error evaluating derived '
#                                                   'field "capacity" on '
#                                                   'ParallelPackBattery(name="Battery" '
#                                                   'id=PS2NjSRL2J9q6tpD5HllPs): '
#                                                   'Unable to calculate '
#                                                   'capacity. Battery '
#                                                   '"PS2NjSRL2J9q6tpD5HllPs" '
#                                                   'has no associated battery '
#                                                   'packs.',
#                                                   'Error evaluating derived '
#                                                   'field "curve" on '
#                                                   'ParallelPackBattery(name="Battery" '
#                                                   'id=PS2NjSRL2J9q6tpD5HllPs): '
#                                                   'Unable to calculate curve. '
#                                                   'Battery '
#                                                   '"PS2NjSRL2J9q6tpD5HllPs" '
#                                                   'has no associated battery '
#                                                   'packs.',
#                                                   'Error evaluating derived '
#                                                   'field "esr" on '
#                                                   'ParallelPackBattery(name="Battery" '
#                                                   'id=PS2NjSRL2J9q6tpD5HllPs): '
#                                                   'Unable to calculate esr. '
#                                                   'Battery '
#                                                   '"PS2NjSRL2J9q6tpD5HllPs" '
#                                                   'has no associated battery '
#                                                   'packs.',
#                                                   'Error evaluating derived '
#                                                   'field '
#                                                   '"idealMaxChargeCurrent" on '
#                                                   'ParallelPackBattery(name="Battery" '
#                                                   'id=PS2NjSRL2J9q6tpD5HllPs): '
#                                                   'Unable to calculate '
#                                                   'idealMaxChargeCurrent. '
#                                                   'Battery '
#                                                   '"PS2NjSRL2J9q6tpD5HllPs" '
#                                                   'has no associated battery '
#                                                   'packs.',
#                                                   'Error evaluating derived '
#                                                   'field '
#                                                   '"idealMaxDischargeCurrent" '
#                                                   'on '
#                                                   'ParallelPackBattery(name="Battery" '
#                                                   'id=PS2NjSRL2J9q6tpD5HllPs): '
#                                                   'Unable to calculate '
#                                                   'idealMaxDischargeCurrent. '
#                                                   'Battery '
#                                                   '"PS2NjSRL2J9q6tpD5HllPs" '
#                                                   'has no associated battery '
#                                                   'packs.',
#                                                   'Error evaluating derived '
#                                                   'field "minSoc" on '
#                                                   'ParallelPackBattery(name="Battery" '
#                                                   'id=PS2NjSRL2J9q6tpD5HllPs): '
#                                                   'Unable to calculate minSoc. '
#                                                   'Battery '
#                                                   '"PS2NjSRL2J9q6tpD5HllPs" '
#                                                   'has no associated battery '
#                                                   'packs.',
#                                                   'Battery has no associated '
#                                                   'battery packs.',
#                                                   'ParallelPackBattery(name="Battery" '
#                                                   'id=PS2NjSRL2J9q6tpD5HllPs) '
#                                                   'is violating a unique '
#                                                   'constraint for Blocks of '
#                                                   'type "Battery" in field '
#                                                   '"name": "Battery".'],
#                        'PS2NjSRPzpNNj38bGSq599': ['Subsystem(name="Power" '
#                                                   'id=PS2NjSRPzpNNj38bGSq599) '
#                                                   'is violating a unique '
#                                                   'constraint for Blocks of '
#                                                   'type "Subsystem" in field '
#                                                   '"name": "Power".'],
#                        'PS2NjSRRy4FmRWQ8bnDSQM': ['Subsystem(name="Command & '
#                                                   'Control" '
#                                                   'id=PS2NjSRRy4FmRWQ8bnDSQM) '
#                                                   'is violating a unique '
#                                                   'constraint for Blocks of '
#                                                   'type "Subsystem" in field '
#                                                   '"name": "Command & '
#                                                   'Control".'],
#                        'PS2NjSRTvTyWbLlvzS7LP3': ['Subsystem(name="Data '
#                                                   'Handling" '
#                                                   'id=PS2NjSRTvTyWbLlvzS7LP3) '
#                                                   'is violating a unique '
#                                                   'constraint for Blocks of '
#                                                   'type "Subsystem" in field '
#                                                   '"name": "Data Handling".'],
#                        'PS2NjSRWzgXdYbCjDDPVyc': ['Subsystem(name="GNC" '
#                                                   'id=PS2NjSRWzgXdYbCjDDPVyc) '
#                                                   'is violating a unique '
#                                                   'constraint for Blocks of '
#                                                   'type "Subsystem" in field '
#                                                   '"name": "GNC".'],
#                        'PS2NjSRYxrw2TdYvHnyn7s': ['Subsystem(name="Thermal" '
#                                                   'id=PS2NjSRYxrw2TdYvHnyn7s) '
#                                                   'is violating a unique '
#                                                   'constraint for Blocks of '
#                                                   'type "Subsystem" in field '
#                                                   '"name": "Thermal".'],
#                        'PS2NjSRbrCqsqrRmKhB2rp': ['Subsystem(name="Structure" '
#                                                   'id=PS2NjSRbrCqsqrRmKhB2rp) '
#                                                   'is violating a unique '
#                                                   'constraint for Blocks of '
#                                                   'type "Subsystem" in field '
#                                                   '"name": "Structure".'],
#                        'root': ['Error evaluating derived field '
#                                 '"pathLossConfig" on Spacecraft(): Expected at '
#                                 'most 1 `PathLossConfig` block, but found 2.',
#                                 'Vehicle must have exactly one Attitude model, '
#                                 'found 2',
#                                 'Power Module requires exactly one Battery.',
#                                 'Exactly one Data Model is required.',
#                                 'Power Module requires exactly one Power '
#                                 'Model.',
#                                 'Power Module requires exactly one Power '
#                                 'Processor.']},
#             'warnings': {'PS2NjSThprBmJpW62tg8Hx': ['Load state "Actuated" on '
#                                                     'component "RCS_Load" has '
#                                                     'no assigned routines and '
#                                                     'will never be active.']}},
#  'lvlhAxes': None,
#  'mass': 120.0,
#  'migrated': 'BaseCdhAgent_0062',
#  'missionOrbit': None,
#  'orbitNumber': 0,
#  'orbitalElements': None,
#  'pathLossConfig': None,
#  'photometricModel': {'bondAlbedo': 0.2, 'sphericalRadius': {'m': 1.0}},
#  'pointingErrorAngle': None,
#  'pointingModesMainRoutine': 'PLCZKQWpjfNLcRbLg65yw6',
#  'position': None,
#  'positionSolution': None,
#  'positionSolutionError': None,
#  'powerProcessor': 'NSghYm2RqDibih0igHFc-',
#  'powerTimeStepLimiter': None,
#  'predictiveAngularVelocitySolution': None,
#  'predictiveAngularVelocitySolutionError': None,
#  'predictiveAttitudeSolution': None,
#  'predictiveAttitudeSolutionError': None,
#  'predictiveAttitudeSolutionErrorAngle': None,
#  'predictivePositionSolution': None,
#  'predictivePositionSolutionError': None,
#  'predictiveVelocitySolution': None,
#  'predictiveVelocitySolutionError': None,
#  'receiveLinks': [],
#  'selfId': None,
#  'shadow': None,
#  'speed': None,
#  'srpTorque': [0.0, 0.0, 0.0],
#  'thermalTimeStepLimiter': None,
#  'timeStepConstraints': {'cdh': {'max': 10.0, 'min': 0.1},
#                          'gnc': {'max': 10.0, 'min': 0.1},
#                          'power': {'max': 10.0, 'min': 1e-06},
#                          'thermal': {'max': 30.0, 'min': 1.0}},
#  'torque': [0.0, 0.0, 0.0],
#  'transmitLinks': [],
#  'type': 'Spacecraft',
#  'velocity': None,
#  'velocitySolution': None,
#  'velocitySolutionError': None,
#  'visible': True}

# %%
def clone_template_as_new_repo(
    api_key: str,
    workspace_id: str,
    block_schema: dict,
    template_name: str,
):
    # 1) spin up a new Spacecraft repo + branch
    client = SedaroApiClient(api_key=api_key)
    repo = client.Repository.create(
        name=template_name,
        metamodelType="Spacecraft",
        workspace=workspace_id,
    )

    # 2) wrap its branch as an AgentTemplateBranch
    new_branch_id = repo.branches[0].id
    branch = client.agent_template(new_branch_id)

    # 3) build a map of (type,name)→id for all the default blocks already in the new branch
    existing = branch.data["blocks"]
    existing_by_type_name = {
        (blk["type"], blk.get("name")): bid
        for bid, blk in existing.items()
    }



    # 4) build our ref_map: old_id → either the real new-branch ID (for defaults)
    #    or a “$old_id” placeholder (for everything else)
    ref_map = {}
    for old_id, blk in existing.items():
        key = (blk["type"], blk.get("name"))
        if key in existing_by_type_name:
            # reuse this default
            ref_map[old_id] = existing_by_type_name[key]
        else:
            # create afresh
            ref_map[old_id] = f"${old_id}"

    delete_items = []
    for old_id, blk in existing.items():
        ref_id = ref_map[old_id]
        if not isinstance(ref_id, str) or not ref_id.startswith("$"):
            # we’re reusing an existing block → skip creation
            continue

        # build your new block entry
        b = {"id": ref_id, "type": blk["type"]}
        for k, v in blk.items():
            if k in ("id", "type"):
                continue

            # remap any string or list of strings that point at other old_ids
            if isinstance(v, str) and v in ref_map:
                b[k] = ref_map[v]
            elif (
                isinstance(v, list)
                and all(isinstance(x, str) and x in ref_map for x in v)
            ):
                b[k] = [ref_map[x] for x in v]
            else:
                b[k] = v

        delete_items.append(b)

    ref_map = {}
    for old_id, blk in block_schema.items():
        key = (blk["type"], blk.get("name"))
        if key in existing_by_type_name:
            # reuse this default
            ref_map[old_id] = existing_by_type_name[key]
        else:
            # create afresh
            ref_map[old_id] = f"${old_id}"

    # 5) turn block_schema → a single payload array, skipping any old_id that
    #    mapped to an existing ID (i.e. those defaults we’re reusing)
    payload = []
    for old_id, blk in block_schema.items():
        ref_id = ref_map[old_id]
        if not isinstance(ref_id, str) or not ref_id.startswith("$"):
            # we’re reusing an existing block → skip creation
            continue

        # build your new block entry
        b = {"id": ref_id, "type": blk["type"]}
        for k, v in blk.items():
            if k in ("id", "type"):
                continue

            # remap any string or list of strings that point at other old_ids
            if isinstance(v, str) and v in ref_map:
                b[k] = ref_map[v]
            elif (
                isinstance(v, list)
                and all(isinstance(x, str) and x in ref_map for x in v)
            ):
                b[k] = [ref_map[x] for x in v]
            else:
                b[k] = v

        payload.append(b)

    # 6) one atomic patch: create all our non‐default blocks in one go
    resp = branch.update(
        delete=delete_items,
        blocks=payload,
        include_response=True
    )

    print("✅ Created/updated:", resp["crud"]["blocks"])
    return branch
# usage
new_branch = clone_template_as_new_repo(
    api_key=API_KEY,
    workspace_id=WORKSPACE_ID,
    block_schema=agent_template_branch.data["blocks"],
    template_name="Clone"
)
# Out:
# ✅ Created/updated: ['NSghWfrUj9OyAK8OBAXa-', 'NSghYm2RqDibih0igHFc-', 'NSghaQGUD5XkZv-hq4TTV', 'NSghcbxRIX9eXogEB0li-', 'NSgheitRQ51bMoH_95sZk', 'NSghgp0ThH8gNv5Ady03k', 'NSghpotSFHj43o7HNUfo-', 'PLCZKQWpjfNLcRbLg65yw6', 'PS2RplQSj4BWmhzMmPjhcw', 'PS2RplQVhDb66QvJmsYCLW', 'PS2RplQXbXTTTvk39J6CTw', 'PS2RplQZb3WgRT4M5GdMxL', 'PS2RplQcYr6NvVYKWhqzyr', 'PS2RplQfddhqtNpYBD8cYb', 'PS2RplQhbq9mV4CQYJ484g', 'PS2RplQkX5MLSMlQp2Yx9l', 'PS2RplQmYcz85mRZRnhsn4', 'PS2RplQpSdSzqNm3fC2ncl', 'PS2RplQrTgjfmtVf2R5jwV', 'PS2RplQtQkHnDQRmZfytDQ', 'PS2RplQwSsF2nJMYRQYqjl', 'PS2RplQyTpHCMHkTCtPrXh', 'PS2RplR2NgZCM8HJz8vfC8', 'PS2RplR4RkSYB57M7Rwrzj', 'PS2RplR6NGYpbWNWvsfz5g', 'PS2RplR8Mlg7t4RchpfCGP', 'PS2RplRBHpkr52zqmLq4Py', 'PS2RplRDKxzT3cz5mYhBT2', 'PS2RplRGKGyzHdcYdSvMdD', 'PS2RplRJKhvy2r29j9RzZg', 'PS2RplRLFKmXZBr2xy474m', 'PS2RplRNGKcBFCdJrPkzdP', 'PS2RplRQHZ8kRBTvyjZdMR', 'PS2RplRSCLhKBQhFQtHL6G', 'PS2RplRVF7NL3RWQlL79sw', 'PS2RplRXBH8vBwbkxK8BSw', 'PS2RplRZ8m9X7MxYjppGvG', 'PS2RplRc5vNmd8SfqM8tt7', 'PS2RplRf8rKBtGxCpRp8Vk', 'PS2RplRh6whf5P486RhkDH', 'PS2RplRk46vVdbNPcvMmd3', 'PS2RplRm3bxQRSWmy8K2Lx', 'PS2RplRp3BbjGk9tf95v2n', 'PS2RplRr2JgpxWMHtVKbJH', 'PS2RplRt2g9kmQzHmknwHF', 'PS2RplRvvm2Cm9tXnLfWJf', 'PS2RplRxzBk6BTZbbCXN6W', 'PS2RplRzzBrQbxt2sqL5r2', 'PS2RplS3t8SQ9BcfP7lVGH', 'PS2RplS5wmfGRv6W6hMLYf', 'PS2RplS7sGZ9DcFbM5SKbh', 'PS2RplS9pwKYFJWxw4tfzR', 'PS2RplSCpf5QwxymtvbzSX']

# %%
print(agent_template_branch.data.keys())
# Out:
# dict_keys(['_abstractBlockTypes', '_blockNames', '_quantityKinds', '_relationships', '_supers', 'activeCommInterfaces', 'activePointingMode', 'activeRoutines', 'angularAcceleration', 'angularMomentum', 'angularMomentumMagnitude', 'angularVelocity', 'angularVelocityError', 'angularVelocitySolution', 'angularVelocitySolutionError', 'annotations', 'attitude', 'attitudeError', 'attitudeSolution', 'attitudeSolutionError', 'attitudeSolutionErrorAngle', 'beta', 'blocks', 'cadFileName', 'cadKey', 'cadScaleFactor', 'cadSignedUrl', 'cdhTimeStepLimiter', 'commandedAngularRates', 'commandedAttitude', 'definitiveAngularVelocitySolution', 'definitiveAngularVelocitySolutionError', 'definitiveAttitudeSolution', 'definitiveAttitudeSolutionError', 'definitiveAttitudeSolutionErrorAngle', 'definitivePositionSolution', 'definitivePositionSolutionError', 'definitiveVelocitySolution', 'definitiveVelocitySolutionError', 'dragTorque', 'dynamicCenterOfMass', 'dynamicInertia', 'dynamicMass', 'earthCoverage', 'earthCoverageGrid', 'enabledModules', 'enuAxes', 'estimatedMagneticFieldVector', 'gncTimeStepLimiter', 'gravityGradientTorque', 'hidingRoutines', 'index', 'inertia', 'initialCenterOfMass', 'issues', 'lvlhAxes', 'mass', 'migrated', 'missionOrbit', 'orbitNumber', 'orbitalElements', 'pathLossConfig', 'photometricModel', 'pointingErrorAngle', 'pointingModesMainRoutine', 'position', 'positionSolution', 'positionSolutionError', 'powerProcessor', 'powerTimeStepLimiter', 'predictiveAngularVelocitySolution', 'predictiveAngularVelocitySolutionError', 'predictiveAttitudeSolution', 'predictiveAttitudeSolutionError', 'predictiveAttitudeSolutionErrorAngle', 'predictivePositionSolution', 'predictivePositionSolutionError', 'predictiveVelocitySolution', 'predictiveVelocitySolutionError', 'receiveLinks', 'selfId', 'shadow', 'speed', 'srpTorque', 'thermalTimeStepLimiter', 'timeStepConstraints', 'torque', 'transmitLinks', 'type', 'velocity', 'velocitySolution', 'velocitySolutionError', 'visible'])

# %%
## future plan
# figure out how to prompt schema to drop all the keys and things we can change
# sysMl to schema round trip
