# %%
from sedaro import SedaroApiClient
from pprint import pprint
API_KEY = "PKDqMrtcTK4plJgL7qVlQD.0xQph1lyKzd-pV0-ZL7bRIH7BX54Yjqbz6tluwut3Hvp8XE-RVbfHSz2o5vC77scUhg2xBFuBybplxY6FyXXMQ"
TEMP_AGENT_REPO_BRANCH_ID = "PRkHJlBrpwLDCqPqfbkdrb" # Specific Repo of the Templated agent 
SCENARIO_BRANCH_VERSION_ID = "PRx5rSwrGfkK4n9vFXmVbt" # Version 2
WORKSPACE_ID = "PQtnGZNNPdzZM5JdVhP5P9" # Violet/Ethreal workspace

# %%
# Define modules
sedaro = SedaroApiClient(api_key = API_KEY)
# agent template is only for satellite model (agent), and don't copy the model repo ID, only the branch ID (version)
agent_template_branch = sedaro.agent_template(TEMP_AGENT_REPO_BRANCH_ID) # we are going to change this templated agent

# %%
block_schema = agent_template_branch.data['blocks']
pprint(agent_template_branch.data['blocks'])
# print(block_schema['id'])
# Out:
# {'NSghWfrUj9OyAK8OBAXa-': {'annotations': {'$': {'subsystem': 'Power'}},
#                            'capacity': 10.05,
#                            'current': 0.0,
#                            'curve': [[0.0,
#                                       0.008,
#                                       0.02,
#                                       0.051,
#                                       0.105,
#                                       0.159,
#                                       0.221,
#                                       0.281,
#                                       0.359,
#                                       0.432,
#                                       0.496,
#                                       0.574,
#                                       0.631,
#                                       0.691,
#                                       0.76,
#                                       0.822,
#                                       0.881,
#                                       0.942,
#                                       1.0],
#                                      [2.545,
#                                       2.757,
#                                       2.933,
#                                       3.142,
#                                       3.304,
#                                       3.394,
#                                       3.463,
#                                       3.503,
#                                       3.553,
#                                       3.603,
#                                       3.649,
#                                       3.719,
#                                       3.775,
#                                       3.825,
#                                       3.878,
#                                       3.944,
#                                       4.017,
#                                       4.08,
#                                       4.163]],
#                            'disabled': False,
#                            'eocVoltageOverride': None,
#                            'esr': 0.0007499999999999999,
#                            'id': 'NSghWfrUj9OyAK8OBAXa-',
#                            'idealMaxChargeCurrent': 4.875,
#                            'idealMaxDischargeCurrent': 19.5,
#                            'initialSoc': 1.0,
#                            'maxChargeCurrent': None,
#                            'maxChargeCurrentOverride': None,
#                            'maxChargePower': None,
#                            'maxChargeVoltage': None,
#                            'maxDischargeCurrentOverride': None,
#                            'minSoc': 0.0,
#                            'minSocOverride': None,
#                            'name': 'Battery',
#                            'packs': ['PRx5qGqQD59tCW4V9tBGQb'],
#                            'power': 0.0,
#                            'powerProcessor': 'NSghYm2RqDibih0igHFc-',
#                            'soc': 1.0,
#                            'terminateAtMinSoc': True,
#                            'type': 'ParallelPackBattery',
#                            'voc': None,
#                            'voltage': None},
#  'NSghYm2RqDibih0igHFc-': {'activeDataMode': None,
#                            'activeLoadState': None,
#                            'annotations': {'$': {'subsystem': 'Power'}},
#                            'availableSolarRootPower': None,
#                            'battery': 'NSghWfrUj9OyAK8OBAXa-',
#                            'busRegulators': [],
#                            'coldMargin': None,
#                            'coldTempRating': {'degC': -40.0},
#                            'controllerBusCurrent': None,
#                            'cotsTemplate': '',
#                            'dataModes': [],
#                            'dataModesMainRoutine': None,
#                            'dataSinks': [],
#                            'dataSources': [],
#                            'dataStorage': None,
#                            'disabled': False,
#                            'dissipations': None,
#                            'dynamicallyLoadedComponents': ['PRx7YwymYJgtlTDBjPKfJG',
#                                                            'PRybm3zT77x3kCSSYHCKgG',
#                                                            'PRybmF9qkFSZFVf2gxYSk5'],
#                            'hotMargin': None,
#                            'hotTempRating': {'degC': 100.0},
#                            'id': 'NSghYm2RqDibih0igHFc-',
#                            'loadStates': [],
#                            'loadStatesMainRoutine': None,
#                            'loads': ['PRzxVRhjClS9dvGScckfcL',
#                                      'PRzxWlK7DBvXszkNRR8PHr',
#                                      'PRzxXwjwBhbBBpCvf8nK24'],
#                            'manufacturer': '',
#                            'name': 'Default Power Processor',
#                            'outputPowers': None,
#                            'partNumber': '',
#                            'powerConsumed': 0.0,
#                            'readRate': None,
#                            'solarArrays': ['PRxly23gP8SJPKTB8254H9'],
#                            'solarRootPower': None,
#                            'storage': None,
#                            'subsystem': 'NSghaQGUD5XkZv-hq4TTV',
#                            'temperature': {'degC': 20.0},
#                            'thermalCapacitance': 1000.0,
#                            'topologyParams': {'bcrEfficiency': 0.9,
#                                               'outputPowerRating': 300.0},
#                            'type': 'SingleConvMpptPowerProcessor',
#                            'writeRate': None},
#  'NSghaQGUD5XkZv-hq4TTV': {'annotations': {},
#                            'category': 'POWER',
#                            'components': ['NSghYm2RqDibih0igHFc-',
#                                           'PRx5qGqQD59tCW4V9tBGQb',
#                                           'PRxCZXTtztSWPPBtFTct5m'],
#                            'disabled': False,
#                            'dissipations': None,
#                            'id': 'NSghaQGUD5XkZv-hq4TTV',
#                            'name': 'Power',
#                            'type': 'Subsystem'},
#  'NSghcbxRIX9eXogEB0li-': {'annotations': {},
#                            'category': 'CDH',
#                            'components': ['PS2PDPqzNwbpcH3mH2LhsF'],
#                            'disabled': False,
#                            'dissipations': None,
#                            'id': 'NSghcbxRIX9eXogEB0li-',
#                            'name': 'Command & Control',
#                            'type': 'Subsystem'},
#  'NSgheitRQ51bMoH_95sZk': {'annotations': {},
#                            'category': 'DATA_HANDLING',
#                            'components': ['PRknf6HwQqzlsFbww9hjkF',
#                                           'PRknffDzvSqr6KPd2RKybc'],
#                            'disabled': False,
#                            'dissipations': None,
#                            'id': 'NSgheitRQ51bMoH_95sZk',
#                            'name': 'Data Handling',
#                            'type': 'Subsystem'},
#  'NSghgp0ThH8gNv5Ady03k': {'annotations': {},
#                            'category': 'GNC',
#                            'components': ['PRx7YwymYJgtlTDBjPKfJG',
#                                           'PRx85VpXxtFcKFVZcYBq4T',
#                                           'PRybm3zT77x3kCSSYHCKgG',
#                                           'PRybmF9qkFSZFVf2gxYSk5'],
#                            'disabled': False,
#                            'dissipations': None,
#                            'id': 'NSghgp0ThH8gNv5Ady03k',
#                            'name': 'GNC',
#                            'type': 'Subsystem'},
#  'NSghj1hTM9mz2Vl08G5rk': {'annotations': {},
#                            'category': 'THERMAL',
#                            'components': [],
#                            'disabled': False,
#                            'dissipations': None,
#                            'id': 'NSghj1hTM9mz2Vl08G5rk',
#                            'name': 'Thermal',
#                            'type': 'Subsystem'},
#  'NSghkyoTLeQzaNfeeckQV': {'annotations': {},
#                            'category': 'STRUCTURE',
#                            'components': [],
#                            'disabled': False,
#                            'dissipations': None,
#                            'id': 'NSghkyoTLeQzaNfeeckQV',
#                            'name': 'Structure',
#                            'type': 'Subsystem'},
#  'NSghpotSFHj43o7HNUfo-': {'activeSubroutine': None,
#                            'annotations': {'$': {'subsystem': 'Command & '
#                                                               'Control'}},
#                            'disabled': False,
#                            'id': 'NSghpotSFHj43o7HNUfo-',
#                            'isActive': False,
#                            'mainRoutine': 'PLCZKQWpjfNLcRbLg65yw6',
#                            'name': 'Point Nadir',
#                            'parentRoutines': ['PLCZKQWpjfNLcRbLg65yw6'],
#                            'pathToActiveLeaf': [],
#                            'subroutines': [],
#                            'timeSinceActive': {'day': 1000000.0},
#                            'timeSinceInactive': {'day': 0.0},
#                            'timeStepDriver': [],
#                            'type': 'Routine'},
#  'N_dA5fnT5DwNn40QSKR4V': {'annotations': {'$': {'subsystem': 'GNC'}},
#                            'definitionParams': {'vector': [1.0, 0.0, 0.0]},
#                            'disabled': False,
#                            'geocenterAngle': None,
#                            'heliocenterAngle': None,
#                            'id': 'N_dA5fnT5DwNn40QSKR4V',
#                            'name': '+X',
#                            'type': 'BodyFrameVector',
#                            'unitVector': [1.0, 0.0, 0.0]},
#  'N_dAvrMSdmYcjRnM1qKSV': {'annotations': {'$': {'subsystem': 'GNC'}},
#                            'definitionParams': {'vector': [0.0, 1.0, 0.0]},
#                            'disabled': False,
#                            'geocenterAngle': None,
#                            'heliocenterAngle': None,
#                            'id': 'N_dAvrMSdmYcjRnM1qKSV',
#                            'name': '+Y',
#                            'type': 'BodyFrameVector',
#                            'unitVector': [0.0, 1.0, 0.0]},
#  'N_dB7gWR61wdN8AmaTK9F': {'annotations': {'$': {'subsystem': 'GNC'}},
#                            'definitionParams': {'vector': [0.0, 0.0, 1.0]},
#                            'disabled': False,
#                            'geocenterAngle': None,
#                            'heliocenterAngle': None,
#                            'id': 'N_dB7gWR61wdN8AmaTK9F',
#                            'name': '+Z',
#                            'type': 'BodyFrameVector',
#                            'unitVector': [0.0, 0.0, 1.0]},
#  'N_dBDWdUEiQQIB7eb91fV': {'annotations': {'$': {'subsystem': 'GNC'}},
#                            'definitionParams': {'vector': [-1.0, 0.0, 0.0]},
#                            'disabled': False,
#                            'geocenterAngle': None,
#                            'heliocenterAngle': None,
#                            'id': 'N_dBDWdUEiQQIB7eb91fV',
#                            'name': '-X',
#                            'type': 'BodyFrameVector',
#                            'unitVector': [-1.0, 0.0, 0.0]},
#  'N_dBGp6Ri9NCGOtCqElJV': {'annotations': {'$': {'subsystem': 'GNC'}},
#                            'definitionParams': {'vector': [0.0, -1.0, 0.0]},
#                            'disabled': False,
#                            'geocenterAngle': None,
#                            'heliocenterAngle': None,
#                            'id': 'N_dBGp6Ri9NCGOtCqElJV',
#                            'name': '-Y',
#                            'type': 'BodyFrameVector',
#                            'unitVector': [0.0, -1.0, 0.0]},
#  'N_dBJ7DT1HEtYaCVqbDzV': {'annotations': {'$': {'subsystem': 'GNC'}},
#                            'definitionParams': {'vector': [0.0, 0.0, -1.0]},
#                            'disabled': False,
#                            'geocenterAngle': None,
#                            'heliocenterAngle': None,
#                            'id': 'N_dBJ7DT1HEtYaCVqbDzV',
#                            'name': '-Z',
#                            'type': 'BodyFrameVector',
#                            'unitVector': [0.0, 0.0, -1.0]},
#  'NcT6YjPRD1X2-OCHQVM1F': {'annotations': {'$': {'subsystem': 'GNC'}},
#                            'disabled': False,
#                            'id': 'NcT6YjPRD1X2-OCHQVM1F',
#                            'type': 'OrbitalAttitudeDynamics'},
#  'PJzkGkkhSMSrtSpL98vSgr': {'angularVelocitySolution': None,
#                             'annotations': {'$': {'subsystem': 'GNC'}},
#                             'attitudeSolution': None,
#                             'clock': None,
#                             'covariance': None,
#                             'definitiveAngularVelocitySolution': None,
#                             'definitiveAttitudeSolution': None,
#                             'definitiveCovariance': None,
#                             'disabled': False,
#                             'id': 'PJzkGkkhSMSrtSpL98vSgr',
#                             'name': 'Ideal AD Algorithm',
#                             'oneSigmaAngularVelocityError': {'deg/s': 0.0},
#                             'oneSigmaPitchError': {'deg': 0.0},
#                             'oneSigmaRollError': {'deg': 0.0},
#                             'oneSigmaYawError': {'deg': 0.0},
#                             'predictiveAngularVelocitySolution': None,
#                             'predictiveAttitudeSolution': None,
#                             'predictiveCovariance': None,
#                             'processNoise': 1e-08,
#                             'type': 'GenericAdAlgorithm'},
#  'PJzkLbHx2W3vg8fmLMCbcs': {'annotations': {'$': {'subsystem': 'GNC'}},
#                             'clock': None,
#                             'correctSensorOffsets': False,
#                             'covariance': None,
#                             'definitiveCovariance': None,
#                             'definitivePositionSolution': None,
#                             'definitiveVelocitySolution': None,
#                             'disabled': False,
#                             'id': 'PJzkLbHx2W3vg8fmLMCbcs',
#                             'name': 'Ideal OD Algorithm',
#                             'oneSigmaPositionError': {'km': 0.0},
#                             'oneSigmaVelocityError': {'km/s': 0.0},
#                             'positionSolution': None,
#                             'predictiveCovariance': None,
#                             'predictivePositionSolution': None,
#                             'predictiveVelocitySolution': None,
#                             'processNoise': 1e-06,
#                             'type': 'GenericOdAlgorithm',
#                             'velocitySolution': None},
#  'PK3PBjf4t6t8NzB38dfcHg': {'annotations': {},
#                             'coldTempRating': {'degC': -200.0},
#                             'diffuseSolarReflectivity': 0.2,
#                             'disabled': False,
#                             'hotTempRating': {'degC': 200.0},
#                             'id': 'PK3PBjf4t6t8NzB38dfcHg',
#                             'irEmissivity': 0.6,
#                             'manufacturer': '',
#                             'partNumber': 'Back Aluminized Kapton MLI',
#                             'solarAbsorptivity': 0.3,
#                             'specularSolarReflectivity': 0.5,
#                             'type': 'SurfaceMaterial'},
#  'PK3PC3RhLz2bxfPgmKkCMv': {'annotations': {},
#                             'coldTempRating': {'degC': -200.0},
#                             'diffuseSolarReflectivity': 0.04,
#                             'disabled': False,
#                             'hotTempRating': {'degC': 200.0},
#                             'id': 'PK3PC3RhLz2bxfPgmKkCMv',
#                             'irEmissivity': 0.87,
#                             'manufacturer': '',
#                             'partNumber': 'Black Z306 Paint',
#                             'solarAbsorptivity': 0.95,
#                             'specularSolarReflectivity': 0.01,
#                             'type': 'SurfaceMaterial'},
#  'PK3PCG3sz3M77RHTgT689V': {'annotations': {},
#                             'coldTempRating': {'degC': -200.0},
#                             'diffuseSolarReflectivity': 0.1,
#                             'disabled': False,
#                             'hotTempRating': {'degC': 200.0},
#                             'id': 'PK3PCG3sz3M77RHTgT689V',
#                             'irEmissivity': 0.8,
#                             'manufacturer': '',
#                             'partNumber': 'Optical Solar Reflector',
#                             'solarAbsorptivity': 0.1,
#                             'specularSolarReflectivity': 0.8,
#                             'type': 'SurfaceMaterial'},
#  'PK3PCQdVjMpgKlvtsnydXd': {'annotations': {},
#                             'coldTempRating': {'degC': -200.0},
#                             'diffuseSolarReflectivity': 0.5,
#                             'disabled': False,
#                             'hotTempRating': {'degC': 200.0},
#                             'id': 'PK3PCQdVjMpgKlvtsnydXd',
#                             'irEmissivity': 0.88,
#                             'manufacturer': '',
#                             'partNumber': 'White A276 Paint',
#                             'solarAbsorptivity': 0.23,
#                             'specularSolarReflectivity': 0.27,
#                             'type': 'SurfaceMaterial'},
#  'PK3PCfJQrr3G2jdPskKPVn': {'annotations': {'$': {'subsystem': 'Thermal'}},
#                             'coldTempRating': {'degC': -40.0},
#                             'disabled': False,
#                             'hotTempRating': {'degC': 200.0},
#                             'id': 'PK3PCfJQrr3G2jdPskKPVn',
#                             'manufacturer': 'Thermagon, Inc.',
#                             'name': 'T-pli 200',
#                             'partNumber': '',
#                             'resistivity': 0.167,
#                             'type': 'ThermalInterfaceMaterial'},
#  'PK3PCpCJRn6LpwvhWzNtsb': {'annotations': {'$': {'subsystem': 'Power'}},
#                             'capacity': 3.35,
#                             'curve': [[0.0,
#                                        0.008,
#                                        0.02,
#                                        0.051,
#                                        0.105,
#                                        0.159,
#                                        0.221,
#                                        0.281,
#                                        0.359,
#                                        0.432,
#                                        0.496,
#                                        0.574,
#                                        0.631,
#                                        0.691,
#                                        0.76,
#                                        0.822,
#                                        0.881,
#                                        0.942,
#                                        1.0],
#                                       [2.545,
#                                        2.757,
#                                        2.933,
#                                        3.142,
#                                        3.304,
#                                        3.394,
#                                        3.463,
#                                        3.503,
#                                        3.553,
#                                        3.603,
#                                        3.649,
#                                        3.719,
#                                        3.775,
#                                        3.825,
#                                        3.878,
#                                        3.944,
#                                        4.017,
#                                        4.08,
#                                        4.163]],
#                             'disabled': False,
#                             'esr': 0.00225,
#                             'id': 'PK3PCpCJRn6LpwvhWzNtsb',
#                             'manufacturer': 'Panasonic',
#                             'maxChargeCurrent': 1.625,
#                             'maxDischargeCurrent': 6.5,
#                             'minSoc': 0.0,
#                             'partNumber': 'NCR18650B',
#                             'type': 'BatteryCell'},
#  'PK3PCxH88PX2DzVz6MCyf8': {'annotations': {'$': {'subsystem': 'Power'}},
#                             'disabled': False,
#                             'id': 'PK3PCxH88PX2DzVz6MCyf8',
#                             'manufacturer': 'Spectrolab',
#                             'maxPowerCurrent': 0.4833,
#                             'maxPowerVoltage': 2.435,
#                             'numJunctions': 3,
#                             'openCircuitVoltage': 2.75,
#                             'partNumber': 'XTE-SF 27 cm^2',
#                             'shortCircuitCurrent': 0.5022,
#                             'type': 'SolarCell'},
#  'PK3PG3PNFkJPsPWKkW4tj5': {'annotations': {'$': {'subsystem': 'Thermal'}},
#                             'coldTempRating': {'degC': -30.0},
#                             'disabled': False,
#                             'hotTempRating': {'degC': 150.0},
#                             'id': 'PK3PG3PNFkJPsPWKkW4tj5',
#                             'manufacturer': 'Saint-Gobain',
#                             'name': 'C675',
#                             'partNumber': '',
#                             'resistivity': 0.909,
#                             'type': 'ThermalInterfaceMaterial'},
#  'PK3PT6mfWX5y7VqkFmqjS3': {'annotations': {'$': {'subsystem': 'Thermal'}},
#                             'coldTempRating': {'degC': -20.0},
#                             'disabled': False,
#                             'hotTempRating': {'degC': 150.0},
#                             'id': 'PK3PT6mfWX5y7VqkFmqjS3',
#                             'manufacturer': 'The Bergquist Company, Inc.',
#                             'name': 'Poly-pad',
#                             'partNumber': '',
#                             'resistivity': 1.111,
#                             'type': 'ThermalInterfaceMaterial'},
#  'PK3PZtlk7jvSLKbSpKcT2W': {'annotations': {'$': {'subsystem': 'Thermal'}},
#                             'coldTempRating': {'degC': -100.0},
#                             'disabled': False,
#                             'hotTempRating': {'degC': 300.0},
#                             'id': 'PK3PZtlk7jvSLKbSpKcT2W',
#                             'manufacturer': '',
#                             'name': 'Al 6061-T6',
#                             'partNumber': '',
#                             'resistivity': 0.006,
#                             'type': 'ThermalInterfaceMaterial'},
#  'PLCZKQWpjfNLcRbLg65yw6': {'activeSubroutine': None,
#                             'annotations': {'$': {'subsystem': 'Command & '
#                                                                'Control'}},
#                             'defaultSubroutine': 'NSghpotSFHj43o7HNUfo-',
#                             'disabled': False,
#                             'id': 'PLCZKQWpjfNLcRbLg65yw6',
#                             'isActive': False,
#                             'logicalConfigurations': ['PRkntJD7kxrMfhqj8t3w79',
#                                                       'PRx7CgDKGCKNjrjrn8m422',
#                                                       'PRxmBnY9lFfZr2RFTWj4Rv'],
#                             'mainRoutine': 'PLCZKQWpjfNLcRbLg65yw6',
#                             'name': 'Default Main Routine',
#                             'parentRoutines': [],
#                             'pathToActiveLeaf': [],
#                             'subroutines': ['PRknsLRz696YC7rDmSLshR',
#                                             'NSghpotSFHj43o7HNUfo-',
#                                             'PRxmBnY7mYHMT6mDLY4szS'],
#                             'timeSinceActive': {'day': 1000000.0},
#                             'timeSinceInactive': {'day': 0.0},
#                             'timeStepDriver': [],
#                             'type': 'CombinationalLogic'},
#  'PPHv6vSHgSf66TMpXRxHDS': {'annotations': {},
#                             'atmospheric': True,
#                             'cloudLayerCeiling': {'km': 10.0},
#                             'cloudLayerFloor': {'km': 1.0},
#                             'clouds': 5,
#                             'disabled': False,
#                             'id': 'PPHv6vSHgSf66TMpXRxHDS',
#                             'rain': None,
#                             'type': 'PathLossConfig'},
#  'PR7Pykl4PhBWGkjsqVs62P': {'annotations': {'$': {'subsystem': 'Thermal'}},
#                             'disabled': False,
#                             'id': 'PR7Pykl4PhBWGkjsqVs62P',
#                             'maxRayCount': 125,
#                             'maxTemperature': {'degK': 2000.0},
#                             'maxTimeStepAngle': {'deg': 10.0},
#                             'minRayCount': 10,
#                             'type': 'ThermalCircuitModel'},
#  'PRB3BpRvNCW28SDWjq3MKW': {'annotations': {'$': {'subsystem': 'Data '
#                                                                'Handling'}},
#                             'disabled': False,
#                             'disabledComms': False,
#                             'disablingRoutines': [],
#                             'id': 'PRB3BpRvNCW28SDWjq3MKW',
#                             'type': 'FullNetworkDataModel'},
#  'PRBf2vJsTCJyGVfjtCrTyZ': {'annotations': {'$': {'subsystem': 'Power'}},
#                             'disabled': False,
#                             'id': 'PRBf2vJsTCJyGVfjtCrTyZ',
#                             'maxTimeStepAngle': {'deg': 10.0},
#                             'type': 'SpacecraftPowerModel'},
#  'PRkZPgrJfKk2D8Pxnx2LjL': {'annotations': {'$': {'subsystem': 'GNC'}},
#                             'disabled': False,
#                             'eclipsed': False,
#                             'estimate': None,
#                             'id': 'PRkZPgrJfKk2D8Pxnx2LjL',
#                             'localPointingDirection': 'NADIR',
#                             'name': 'Nadir - Truth (7MjkYeZ)',
#                             'representation': 'TRUTH',
#                             'truth': None,
#                             'type': 'LocalVector',
#                             'vectorCoordinates': [0.0, 0.0, 0.0]},
#  'PRknWvRwFwNYqMkb4f4YzC': {'acAlgorithm': 'PRxmFfjhrBLYsvM3FDYQjH',
#                             'adAlgorithm': 'PJzkGkkhSMSrtSpL98vSgr',
#                             'annotations': {'$': {'subsystem': 'Command & '
#                                                                'Control'}},
#                             'commandedAngularRates': None,
#                             'commandedAttitude': None,
#                             'disabled': False,
#                             'id': 'PRknWvRwFwNYqMkb4f4YzC',
#                             'isActive': False,
#                             'lockBodyFrameVector': 'N_dBJ7DT1HEtYaCVqbDzV',
#                             'lockVector': 'PRkZPgrJfKk2D8Pxnx2LjL',
#                             'magnetorquerCommands': None,
#                             'name': 'Point Nadir',
#                             'odAlgorithm': 'PJzkLbHx2W3vg8fmLMCbcs',
#                             'reactionWheelCommands': None,
#                             'routines': ['NSghpotSFHj43o7HNUfo-'],
#                             'spinRate': {'rpm': 0.0},
#                             'tcAlgorithm': None,
#                             'type': 'LockSpinPointingMode'},
#  'PRkncWhpKjBlKMQdHvjLth': {'activeArticulationMode': None,
#                             'annotations': {'$': {'subsystem': 'GNC'}},
#                             'articulationAngles': [],
#                             'articulationModes': [],
#                             'articulationModesMainRoutine': None,
#                             'articulations': {},
#                             'attitude': None,
#                             'bodyMask': None,
#                             'boresightBodyFrameVector': 'N_dBJ7DT1HEtYaCVqbDzV',
#                             'calculateEarthViewshed': True,
#                             'disabled': False,
#                             'earthCoverage': None,
#                             'halfAngle': {'deg': 60.0},
#                             'id': 'PRkncWhpKjBlKMQdHvjLth',
#                             'name': 'Antenna FoV',
#                             'relativeAttitude': None,
#                             'sensors': [],
#                             'type': 'CircularFieldOfView',
#                             'visibleEarthArea': None,
#                             'visibleEarthAreaVectors': None},
#  'PRkndgpVsbrNvX45xTGMwx': {'annotations': {'$': {'subsystem': 'Data '
#                                                                'Handling'}},
#                             'disabled': False,
#                             'id': 'PRkndgpVsbrNvX45xTGMwx',
#                             'name': 'Mission Data',
#                             'priority': 1.0,
#                             'type': 'DataType'},
#  'PRknf6HwQqzlsFbww9hjkF': {'activeDataMode': None,
#                             'activeLoadState': None,
#                             'annotations': {},
#                             'coldMargin': None,
#                             'coldTempRating': {'degC': -40.0},
#                             'cotsTemplate': '',
#                             'dataModes': [],
#                             'dataModesMainRoutine': None,
#                             'dataSinks': [],
#                             'dataSources': [],
#                             'dataStorage': None,
#                             'disabled': False,
#                             'dissipations': None,
#                             'fieldOfView': 'PRkncWhpKjBlKMQdHvjLth',
#                             'gainPattern': None,
#                             'gainReferenceX': None,
#                             'hotMargin': None,
#                             'hotTempRating': {'degC': 100.0},
#                             'id': 'PRknf6HwQqzlsFbww9hjkF',
#                             'loadStates': [],
#                             'loadStatesMainRoutine': None,
#                             'manufacturer': '',
#                             'name': 'Antenna',
#                             'partNumber': '',
#                             'peakEirp': None,
#                             'peakGT': None,
#                             'polarizationTiltAngle': {'deg': 45.0},
#                             'powerConsumed': 0.0,
#                             'readRate': None,
#                             'receiveConfigured': False,
#                             'receiveInterfaces': [],
#                             'receiveNoiseTemperature': None,
#                             'rxFrequency': None,
#                             'rxUniformGT': None,
#                             'rxWavelength': None,
#                             'storage': None,
#                             'subsystem': 'NSgheitRQ51bMoH_95sZk',
#                             'temperature': {'degC': 20.0},
#                             'thermalCapacitance': 1000.0,
#                             'transmitConfigured': False,
#                             'transmitInterfaces': ['PRkngd9JJDFBskzmrzbhfm'],
#                             'transmitPower': None,
#                             'txFrequency': None,
#                             'txUniformEirp': None,
#                             'txWavelength': None,
#                             'type': 'Antenna',
#                             'writeRate': None,
#                             'xAxisBody': None},
#  'PRknffDzvSqr6KPd2RKybc': {'activeDataMode': None,
#                             'activeLoadState': None,
#                             'annotations': {},
#                             'coldMargin': None,
#                             'coldTempRating': {'degC': -40.0},
#                             'cotsTemplate': '',
#                             'dataModes': ['PRknhFZ7X78w9dzX64Qn8m'],
#                             'dataModesMainRoutine': None,
#                             'dataSinks': ['PRkngd9JJDFBskzmrzbhfm'],
#                             'dataSources': [],
#                             'dataStorage': None,
#                             'disabled': False,
#                             'dissipations': None,
#                             'hotMargin': None,
#                             'hotTempRating': {'degC': 100.0},
#                             'id': 'PRknffDzvSqr6KPd2RKybc',
#                             'loadStates': [],
#                             'loadStatesMainRoutine': None,
#                             'losInterfaces': ['PRkngd9JJDFBskzmrzbhfm'],
#                             'manufacturer': '',
#                             'modulationType': None,
#                             'name': 'Modem',
#                             'partNumber': '',
#                             'powerConsumed': 0.0,
#                             'protocol': None,
#                             'readRate': None,
#                             'storage': None,
#                             'subsystem': 'NSgheitRQ51bMoH_95sZk',
#                             'temperature': {'degC': 20.0},
#                             'thermalCapacitance': 1000.0,
#                             'type': 'Modem',
#                             'writeRate': None},
#  'PRkngd9JJDFBskzmrzbhfm': {'activeLinkAgent': None,
#                             'activeLinkTarget': None,
#                             'activeLinkTargets': None,
#                             'additionalLosses': 0.0,
#                             'alwaysActive': True,
#                             'annotations': {'$': {'subsystem': 'Data '
#                                                                'Handling'}},
#                             'atmosphericLoss': None,
#                             'averageDataAge': {},
#                             'bitErrorRatio': None,
#                             'bitRate': 0.0,
#                             'canLink': False,
#                             'cloudLoss': None,
#                             'compatibilityId': 'LOS_ANTENNA',
#                             'dataTypes': {'PRkndgpVsbrNvX45xTGMwx': {'priority': None}},
#                             'dataVolume': 0.0,
#                             'directedEnergyDevice': 'PRknf6HwQqzlsFbww9hjkF',
#                             'disabled': False,
#                             'ebNo': None,
#                             'effectiveOnBitRate': 1000.0,
#                             'expectedBitErrors': 0.0,
#                             'frequency': None,
#                             'id': 'PRkngd9JJDFBskzmrzbhfm',
#                             'isActive': False,
#                             'isOpen': False,
#                             'linkLatencies': None,
#                             'linkLatency': None,
#                             'linkMargin': None,
#                             'linkTarget': None,
#                             'linkTargetGroup': None,
#                             'maxBitErrorRatio': None,
#                             'maxDataAge': {},
#                             'minDataAge': {},
#                             'modem': 'PRknffDzvSqr6KPd2RKybc',
#                             'name': 'Downlink',
#                             'onBitRate': 1000.0,
#                             'oneToMany': False,
#                             'passive': False,
#                             'rainLoss': None,
#                             'receiveGT': None,
#                             'receivePointingLoss': None,
#                             'requiredEbNo': None,
#                             'routines': [],
#                             'sink': None,
#                             'snr': None,
#                             'source': 'PRknffDzvSqr6KPd2RKybc',
#                             'spaceLoss': None,
#                             'targetInFov': False,
#                             'targetsCanLink': None,
#                             'targetsInFov': None,
#                             'transmitEirp': None,
#                             'transmitPointingLoss': None,
#                             'type': 'LineOfSightTransmitInterface',
#                             'typeBitRates': {'Mission Data': 0.0},
#                             'typePriority': {'PRkndgpVsbrNvX45xTGMwx': {'priority': 1.0}},
#                             'uncorrectableErrorProbability': None,
#                             'wavelength': None},
#  'PRknhFZ7X78w9dzX64Qn8m': {'alwaysActive': True,
#                             'annotations': {'$': {'subsystem': 'Command & '
#                                                                'Control'}},
#                             'components': ['PRknffDzvSqr6KPd2RKybc'],
#                             'disabled': False,
#                             'id': 'PRknhFZ7X78w9dzX64Qn8m',
#                             'input': {},
#                             'isActive': False,
#                             'name': 'Mission Operation',
#                             'output': {'PRkndgpVsbrNvX45xTGMwx': {'bitRate': 1000.0}},
#                             'routines': [],
#                             'type': 'DataMode'},
#  'PRknqNmldqNZvff74HWZkc': {'annotations': {'$': {'subsystem': 'Command & '
#                                                                'Control'}},
#                             'compliance': None,
#                             'disabled': False,
#                             'id': 'PRknqNmldqNZvff74HWZkc',
#                             'name': 'Target LoS',
#                             'relationship': 'EQUAL',
#                             'scalar': 1.0,
#                             'targetA': None,
#                             'targetParam': 'LO_SIGHT',
#                             'terminator': False,
#                             'type': 'TargetToScalarCondition'},
#  'PRknsLRz696YC7rDmSLshR': {'activeSubroutine': None,
#                             'annotations': {'$': {'subsystem': 'Command & '
#                                                                'Control'}},
#                             'disabled': False,
#                             'id': 'PRknsLRz696YC7rDmSLshR',
#                             'isActive': False,
#                             'mainRoutine': 'PLCZKQWpjfNLcRbLg65yw6',
#                             'name': 'Point at Sat',
#                             'parentRoutines': ['PLCZKQWpjfNLcRbLg65yw6'],
#                             'pathToActiveLeaf': [],
#                             'subroutines': [],
#                             'timeSinceActive': {'day': 1000000.0},
#                             'timeSinceInactive': {'day': 0.0},
#                             'timeStepDriver': [],
#                             'type': 'Routine'},
#  'PRkntJD7kxrMfhqj8t3w79': {'annotations': {'$': {'subsystem': 'Command & '
#                                                                'Control'}},
#                             'combinationalLogicRoutines': ['PLCZKQWpjfNLcRbLg65yw6'],
#                             'compliance': False,
#                             'conditions': ['PRwzRZgLJrlx9bDnf5YW4t'],
#                             'disabled': False,
#                             'id': 'PRkntJD7kxrMfhqj8t3w79',
#                             'maxOccurrenceDuration': None,
#                             'minOccurrenceDuration': None,
#                             'minTimeBetweenOccurrences': None,
#                             'priority': 2,
#                             'routine': 'PRknsLRz696YC7rDmSLshR',
#                             'type': 'LogicalConfiguration'},
#  'PRkntw3tVlwzbxBkQgXw8V': {'annotations': {'$': {'subsystem': 'GNC'}},
#                             'disabled': False,
#                             'eclipsed': False,
#                             'estimate': None,
#                             'id': 'PRkntw3tVlwzbxBkQgXw8V',
#                             'name': 'Ground Target Placeholder - Target Truth '
#                                     '(6Xm1bwj)',
#                             'referenceTarget': None,
#                             'representation': 'TRUTH',
#                             'truth': None,
#                             'type': 'TargetVector'},
#  'PRwzP4dbw3VpMmHmVcKq2N': {'annotations': {'$': {'subsystem': 'GNC'}},
#                             'disabled': False,
#                             'eclipsed': False,
#                             'estimate': None,
#                             'id': 'PRwzP4dbw3VpMmHmVcKq2N',
#                             'name': 'Sat target - Target Truth (pnkkJZj)',
#                             'referenceTarget': None,
#                             'representation': 'TRUTH',
#                             'truth': None,
#                             'type': 'TargetVector'},
#  'PRwzQ7DxCD26fc6l4BlmNc': {'acAlgorithm': 'PRxmFfjhrBLYsvM3FDYQjH',
#                             'adAlgorithm': 'PJzkGkkhSMSrtSpL98vSgr',
#                             'annotations': {'$': {'subsystem': 'Command & '
#                                                                'Control'}},
#                             'commandedAngularRates': None,
#                             'commandedAttitude': None,
#                             'disabled': False,
#                             'id': 'PRwzQ7DxCD26fc6l4BlmNc',
#                             'isActive': False,
#                             'lockBodyFrameVector': 'N_dBJ7DT1HEtYaCVqbDzV',
#                             'lockVector': 'PRwzP4dbw3VpMmHmVcKq2N',
#                             'magnetorquerCommands': None,
#                             'name': 'Point Sat Agent',
#                             'odAlgorithm': 'PJzkLbHx2W3vg8fmLMCbcs',
#                             'reactionWheelCommands': None,
#                             'routines': ['PRknsLRz696YC7rDmSLshR'],
#                             'spinRate': {'rpm': 0.0},
#                             'tcAlgorithm': None,
#                             'type': 'LockSpinPointingMode'},
#  'PRwzRZgLJrlx9bDnf5YW4t': {'annotations': {'$': {'subsystem': 'Command & '
#                                                                'Control'}},
#                             'compliance': None,
#                             'disabled': False,
#                             'id': 'PRwzRZgLJrlx9bDnf5YW4t',
#                             'name': 'Sat LoS',
#                             'relationship': 'EQUAL',
#                             'scalar': 1.0,
#                             'targetA': None,
#                             'targetParam': 'LO_SIGHT',
#                             'terminator': False,
#                             'type': 'TargetToScalarCondition'},
#  'PRx5qGqQD59tCW4V9tBGQb': {'activeDataMode': None,
#                             'activeLoadState': None,
#                             'annotations': {'$': {'subsystem': 'Power'}},
#                             'battery': 'NSghWfrUj9OyAK8OBAXa-',
#                             'capacity': 10.05,
#                             'cell': 'PK3PCpCJRn6LpwvhWzNtsb',
#                             'coldMargin': None,
#                             'coldTempRating': {'degC': -40.0},
#                             'cotsTemplate': '',
#                             'current': None,
#                             'curve': [[0.0,
#                                        0.008,
#                                        0.02,
#                                        0.051,
#                                        0.105,
#                                        0.159,
#                                        0.221,
#                                        0.281,
#                                        0.359,
#                                        0.432,
#                                        0.496,
#                                        0.574,
#                                        0.631,
#                                        0.691,
#                                        0.76,
#                                        0.822,
#                                        0.881,
#                                        0.942,
#                                        1.0],
#                                       [2.545,
#                                        2.757,
#                                        2.933,
#                                        3.142,
#                                        3.304,
#                                        3.394,
#                                        3.463,
#                                        3.503,
#                                        3.553,
#                                        3.603,
#                                        3.649,
#                                        3.719,
#                                        3.775,
#                                        3.825,
#                                        3.878,
#                                        3.944,
#                                        4.017,
#                                        4.08,
#                                        4.163]],
#                             'dataModes': [],
#                             'dataModesMainRoutine': None,
#                             'dataSinks': [],
#                             'dataSources': [],
#                             'dataStorage': 'PRx7NYMnznSr5vZgqzxRj7',
#                             'disabled': False,
#                             'dissipations': None,
#                             'esr': 0.0007499999999999999,
#                             'hotMargin': None,
#                             'hotTempRating': {'degC': 100.0},
#                             'id': 'PRx5qGqQD59tCW4V9tBGQb',
#                             'idealMaxChargeCurrent': 4.875,
#                             'idealMaxDischargeCurrent': 19.5,
#                             'loadStates': [],
#                             'loadStatesMainRoutine': None,
#                             'manufacturer': '',
#                             'minSoc': 0.0,
#                             'name': 'BP1',
#                             'numParallel': 3,
#                             'numSeries': 1,
#                             'partNumber': '',
#                             'powerConsumed': 0.0,
#                             'readRate': None,
#                             'storage': None,
#                             'subsystem': 'NSghaQGUD5XkZv-hq4TTV',
#                             'temperature': {'degC': 20.0},
#                             'thermalCapacitance': 1000.0,
#                             'type': 'BatteryPack',
#                             'writeRate': None},
#  'PRx7CgDKGCKNjrjrn8m422': {'annotations': {'$': {'subsystem': 'Command & '
#                                                                'Control'}},
#                             'combinationalLogicRoutines': ['PLCZKQWpjfNLcRbLg65yw6'],
#                             'compliance': False,
#                             'conditions': [],
#                             'disabled': False,
#                             'id': 'PRx7CgDKGCKNjrjrn8m422',
#                             'maxOccurrenceDuration': None,
#                             'minOccurrenceDuration': None,
#                             'minTimeBetweenOccurrences': None,
#                             'priority': 0,
#                             'routine': 'NSghpotSFHj43o7HNUfo-',
#                             'type': 'LogicalConfiguration'},
#  'PRx7NYMnznSr5vZgqzxRj7': {'annotations': {'$': {'subsystem': 'Data '
#                                                                'Handling'}},
#                             'averageDataAge': {},
#                             'capacity': 1000000,
#                             'component': 'PRx5qGqQD59tCW4V9tBGQb',
#                             'disabled': False,
#                             'fillPercent': 0.0,
#                             'id': 'PRx7NYMnznSr5vZgqzxRj7',
#                             'maxBitRateRead': 10000.0,
#                             'maxBitRateWrite': 10000.0,
#                             'maxDataAge': {},
#                             'minDataAge': {},
#                             'name': 'Data Storage 1',
#                             'queueMethod': 'FIFO',
#                             'readRate': 0.0,
# ...
#                             'temperature': {'degC': 20.0},
#                             'thermalCapacitance': 1000.0,
#                             'topologyParams': {'bcrEfficiency': 0.9,
#                                                'outputPowerRating': 300.0},
#                             'type': 'SingleConvMpptPowerProcessor',
#                             'writeRate': None},
#  'PS2NjSRPzpNNj38bGSq599': {'annotations': {},
#                             'category': 'POWER',
#                             'components': ['PS2NjSRN3vWL7kbR9cSQ22'],
#                             'disabled': False,
#                             'dissipations': None,
#                             'id': 'PS2NjSRPzpNNj38bGSq599',
#                             'name': 'Power',
#                             'type': 'Subsystem'},
#  'PS2NjSRRy4FmRWQ8bnDSQM': {'annotations': {},
#                             'category': 'CDH',
#                             'components': ['PS2NjSTftLgmVtwjDGcyG5'],
#                             'disabled': False,
#                             'dissipations': None,
#                             'id': 'PS2NjSRRy4FmRWQ8bnDSQM',
#                             'name': 'Command & Control',
#                             'type': 'Subsystem'},
#  'PS2NjSRTvTyWbLlvzS7LP3': {'annotations': {},
#                             'category': 'DATA_HANDLING',
#                             'components': [],
#                             'disabled': False,
#                             'dissipations': None,
#                             'id': 'PS2NjSRTvTyWbLlvzS7LP3',
#                             'name': 'Data Handling',
#                             'type': 'Subsystem'},
#  'PS2NjSRWzgXdYbCjDDPVyc': {'annotations': {},
#                             'category': 'GNC',
#                             'components': [],
#                             'disabled': False,
#                             'dissipations': None,
#                             'id': 'PS2NjSRWzgXdYbCjDDPVyc',
#                             'name': 'GNC',
#                             'type': 'Subsystem'},
#  'PS2NjSRYxrw2TdYvHnyn7s': {'annotations': {},
#                             'category': 'THERMAL',
#                             'components': [],
#                             'disabled': False,
#                             'dissipations': None,
#                             'id': 'PS2NjSRYxrw2TdYvHnyn7s',
#                             'name': 'Thermal',
#                             'type': 'Subsystem'},
#  'PS2NjSRbrCqsqrRmKhB2rp': {'annotations': {},
#                             'category': 'STRUCTURE',
#                             'components': [],
#                             'disabled': False,
#                             'dissipations': None,
#                             'id': 'PS2NjSRbrCqsqrRmKhB2rp',
#                             'name': 'Structure',
#                             'type': 'Subsystem'},
#  'PS2NjSRvlHYLSHBgWMKxt6': {'annotations': {'$': {'subsystem': 'GNC'}},
#                             'disabled': False,
#                             'id': 'PS2NjSRvlHYLSHBgWMKxt6',
#                             'type': 'OrbitalAttitudeDynamics'},
#  'PS2NjSSCbw6yWstXPQghQG': {'annotations': {'$': {'subsystem': 'Thermal'}},
#                             'coldTempRating': {'degC': -40.0},
#                             'disabled': False,
#                             'hotTempRating': {'degC': 200.0},
#                             'id': 'PS2NjSSCbw6yWstXPQghQG',
#                             'manufacturer': 'Thermagon, Inc.',
#                             'name': 'T-pli 200',
#                             'partNumber': '',
#                             'resistivity': 0.167,
#                             'type': 'ThermalInterfaceMaterial'},
#  'PS2NjSSKXcmDzpHNHplzpf': {'annotations': {'$': {'subsystem': 'Thermal'}},
#                             'coldTempRating': {'degC': -30.0},
#                             'disabled': False,
#                             'hotTempRating': {'degC': 150.0},
#                             'id': 'PS2NjSSKXcmDzpHNHplzpf',
#                             'manufacturer': 'Saint-Gobain',
#                             'name': 'C675',
#                             'partNumber': '',
#                             'resistivity': 0.909,
#                             'type': 'ThermalInterfaceMaterial'},
#  'PS2NjSSMbWHJvlPsWF5Zvn': {'annotations': {'$': {'subsystem': 'Thermal'}},
#                             'coldTempRating': {'degC': -20.0},
#                             'disabled': False,
#                             'hotTempRating': {'degC': 150.0},
#                             'id': 'PS2NjSSMbWHJvlPsWF5Zvn',
#                             'manufacturer': 'The Bergquist Company, Inc.',
#                             'name': 'Poly-pad',
#                             'partNumber': '',
#                             'resistivity': 1.111,
#                             'type': 'ThermalInterfaceMaterial'},
#  'PS2NjSSPZ8zkfYCPkStb5J': {'annotations': {'$': {'subsystem': 'Thermal'}},
#                             'coldTempRating': {'degC': -100.0},
#                             'disabled': False,
#                             'hotTempRating': {'degC': 300.0},
#                             'id': 'PS2NjSSPZ8zkfYCPkStb5J',
#                             'manufacturer': '',
#                             'name': 'Al 6061-T6',
#                             'partNumber': '',
#                             'resistivity': 0.006,
#                             'type': 'ThermalInterfaceMaterial'},
#  'PS2NjSSTTMfS4gtxZ6bfqX': {'annotations': {},
#                             'atmospheric': True,
#                             'cloudLayerCeiling': {'km': 10.0},
#                             'cloudLayerFloor': {'km': 1.0},
#                             'clouds': 5,
#                             'disabled': False,
#                             'id': 'PS2NjSSTTMfS4gtxZ6bfqX',
#                             'rain': None,
#                             'type': 'PathLossConfig'},
#  'PS2NjSSWWLtCdsThR8MDGC': {'annotations': {'$': {'subsystem': 'Thermal'}},
#                             'disabled': False,
#                             'id': 'PS2NjSSWWLtCdsThR8MDGC',
#                             'maxRayCount': 125,
#                             'maxTemperature': {'degK': 2000.0},
#                             'maxTimeStepAngle': {'deg': 10.0},
#                             'minRayCount': 10,
#                             'type': 'ThermalCircuitModel'},
#  'PS2NjSSYTHH2BqhPjgtlX6': {'annotations': {'$': {'subsystem': 'Data '
#                                                                'Handling'}},
#                             'disabled': False,
#                             'disabledComms': False,
#                             'disablingRoutines': [],
#                             'id': 'PS2NjSSYTHH2BqhPjgtlX6',
#                             'type': 'FullNetworkDataModel'},
#  'PS2NjSSbSt4PZf3Mpqqt8W': {'annotations': {'$': {'subsystem': 'Power'}},
#                             'disabled': False,
#                             'id': 'PS2NjSSbSt4PZf3Mpqqt8W',
#                             'maxTimeStepAngle': {'deg': 10.0},
#                             'type': 'SpacecraftPowerModel'},
#  'PS2NjSSlLV5Mjp8FXBwQ6x': {'agentAzimuth': None,
#                             'agentElevation': None,
#                             'agentId': None,
#                             'alt': None,
#                             'annotations': {},
#                             'atmosphericVisibility': 10.0,
#                             'cloudConfig': None,
#                             'cloudData': None,
#                             'communicatingWithAgent': False,
#                             'disabled': False,
#                             'id': 'PS2NjSSlLV5Mjp8FXBwQ6x',
#                             'lat': None,
#                             'lineOfSight': None,
#                             'lon': None,
#                             'lst': None,
#                             'name': 'Ground Target Placeholder',
#                             'position': None,
#                             'rainData': None,
#                             'range': None,
#                             'rangeRate': None,
#                             'referenceRainfallRate': None,
#                             'relativePosition': None,
#                             'setReferenceRainfallRate': None,
#                             'shadow': None,
#                             'solarAz': None,
#                             'solarEl': None,
#                             'targetAzimuth': None,
#                             'targetElevation': None,
#                             'type': 'GroundTarget',
#                             'velocity': None},
#  'PS2NjST99lqsnXgV4Pvfpt': {'acAlgorithm': 'PRxmFfjhrBLYsvM3FDYQjH',
#                             'adAlgorithm': 'PJzkGkkhSMSrtSpL98vSgr',
#                             'annotations': {'$': {'subsystem': 'Command & '
#                                                                'Control'}},
#                             'commandedAngularRates': None,
#                             'commandedAttitude': None,
#                             'disabled': False,
#                             'id': 'PS2NjST99lqsnXgV4Pvfpt',
#                             'isActive': False,
#                             'lockBodyFrameVector': 'N_dBJ7DT1HEtYaCVqbDzV',
#                             'lockVector': 'PRkntw3tVlwzbxBkQgXw8V',
#                             'magnetorquerCommands': None,
#                             'name': 'Point Target',
#                             'odAlgorithm': 'PJzkLbHx2W3vg8fmLMCbcs',
#                             'reactionWheelCommands': None,
#                             'routines': ['PRxmBnY7mYHMT6mDLY4szS'],
#                             'spinRate': {'rpm': 0.0},
#                             'tcAlgorithm': None,
#                             'type': 'LockSpinPointingMode'},
#  'PS2NjSTC9SmGZnKcNMbRSN': {'agentAzimuth': None,
#                             'agentElevation': None,
#                             'agentId': None,
#                             'alt': None,
#                             'angularVelocity': None,
#                             'annotations': {},
#                             'apparentMagnitude': None,
#                             'attitude': None,
#                             'beta': None,
#                             'communicatingWithAgent': False,
#                             'disabled': False,
#                             'fiducials': [],
#                             'id': 'PS2NjSTC9SmGZnKcNMbRSN',
#                             'lat': None,
#                             'lineOfSight': None,
#                             'lon': None,
#                             'lst': None,
#                             'name': 'Sat target',
#                             'orbitalElements': None,
#                             'position': None,
#                             'range': None,
#                             'rangeRate': None,
#                             'relativePosition': None,
#                             'relativePositionLvlh': None,
#                             'relativeVelocity': None,
#                             'shadow': None,
#                             'solarPhaseAngle': None,
#                             'targetAzimuth': None,
#                             'targetElevation': None,
#                             'type': 'SpaceTarget',
#                             'velocity': None},
#  'PS2NjSTftLgmVtwjDGcyG5': {'activeDataMode': None,
#                             'activeLoadState': None,
#                             'annotations': {},
#                             'coldMargin': None,
#                             'coldTempRating': {'degC': -40.0},
#                             'cotsTemplate': '',
#                             'dataModes': [],
#                             'dataModesMainRoutine': None,
#                             'dataSinks': [],
#                             'dataSources': [],
#                             'dataStorage': None,
#                             'disabled': False,
#                             'dissipations': None,
#                             'hotMargin': None,
#                             'hotTempRating': {'degC': 100.0},
#                             'id': 'PS2NjSTftLgmVtwjDGcyG5',
#                             'loadStates': ['PS2NjSThprBmJpW62tg8Hx'],
#                             'loadStatesMainRoutine': None,
#                             'manufacturer': '',
#                             'name': 'RCS_Load',
#                             'partNumber': '',
#                             'powerConsumed': 0.0,
#                             'readRate': None,
#                             'storage': None,
#                             'subsystem': 'PS2NjSRRy4FmRWQ8bnDSQM',
#                             'temperature': {'degC': 20.0},
#                             'thermalCapacitance': 1000.0,
#                             'type': 'Component',
#                             'writeRate': None},
#  'PS2NjSThprBmJpW62tg8Hx': {'annotations': {'$': {'subsystem': 'Command & '
#                                                                'Control'}},
#                             'component': 'PS2NjSTftLgmVtwjDGcyG5',
#                             'disabled': False,
#                             'efficiency': 0.7,
#                             'id': 'PS2NjSThprBmJpW62tg8Hx',
#                             'isActive': False,
#                             'loads': ['PS2NjSTkqGzftymPjSpCTm'],
#                             'name': 'Actuated',
#                             'powerConsumed': None,
#                             'powerDissipation': None,
#                             'routines': [],
#                             'timeSinceActive': {'day': 0.0},
#                             'type': 'LoadState'},
#  'PS2NjSTkqGzftymPjSpCTm': {'annotations': {'$': {'subsystem': 'Power'}},
#                             'busRegulator': None,
#                             'dipoleMomentMagnitude': None,
#                             'dipoleOrientation': None,
#                             'disabled': False,
#                             'dutyCyclePercentage': None,
#                             'dutyCyclePeriod': None,
#                             'epsOutputType': 'CORE_OUTPUT',
#                             'id': 'PS2NjSTkqGzftymPjSpCTm',
#                             'isActive': None,
#                             'loadState': 'PS2NjSThprBmJpW62tg8Hx',
#                             'name': 'RCS',
#                             'power': 2.0,
#                             'powerConsumed': None,
#                             'powerProcessor': 'PS2NjSRN3vWL7kbR9cSQ22',
#                             'torque': [0.0, 0.0, 0.0],
#                             'type': 'PowerLoad'},
#  'PS2PDPqzNwbpcH3mH2LhsF': {'activeDataMode': None,
#                             'activeLoadState': None,
#                             'annotations': {},
#                             'coldMargin': None,
#                             'coldTempRating': {'degC': -40.0},
#                             'cotsTemplate': '',
#                             'dataModes': [],
#                             'dataModesMainRoutine': None,
#                             'dataSinks': [],
#                             'dataSources': [],
#                             'dataStorage': None,
#                             'disabled': False,
#                             'dissipations': None,
#                             'hotMargin': None,
#                             'hotTempRating': {'degC': 100.0},
#                             'id': 'PS2PDPqzNwbpcH3mH2LhsF',
#                             'loadStates': [],
#                             'loadStatesMainRoutine': None,
#                             'manufacturer': '',
#                             'name': 'RCS_load1',
#                             'partNumber': '',
#                             'powerConsumed': 0.0,
#                             'readRate': None,
#                             'storage': None,
#                             'subsystem': 'NSghcbxRIX9eXogEB0li-',
#                             'temperature': {'degC': 20.0},
#                             'thermalCapacitance': 1000.0,
#                             'type': 'Component',
#                             'writeRate': None}}

# %%
def clone_template_as_new_repo(
    api_key: str,
    workspace_id: str,
    block_schema: dict,
    template_name: str,
):
    # 1) spin up a new Spacecraft repo + branch
    client = SedaroApiClient(api_key=api_key)
    repo = client.Repository.create(
        name=template_name,
        metamodelType="Spacecraft",
        workspace=workspace_id,
    )

    # 2) wrap its branch as an AgentTemplateBranch
    new_branch_id = repo.branches[0].id
    branch = client.agent_template(new_branch_id)

    # 3) build a map of (type,name)→id for all the default blocks already in the new branch
    existing = branch.data["blocks"]
    existing_by_type_name = {
        (blk["type"], blk.get("name")): bid
        for bid, blk in existing.items()
    }



    # 4) build our ref_map: old_id → either the real new-branch ID (for defaults)
    #    or a “$old_id” placeholder (for everything else)
    ref_map = {}
    for old_id, blk in existing.items():
        key = (blk["type"], blk.get("name"))
        if key in existing_by_type_name:
            # reuse this default
            ref_map[old_id] = existing_by_type_name[key]
        else:
            # create afresh
            ref_map[old_id] = f"${old_id}"

    delete_items = []
    for old_id, blk in existing.items():
        ref_id = ref_map[old_id]
        if not isinstance(ref_id, str) or not ref_id.startswith("$"):
            # we’re reusing an existing block → skip creation
            continue

        # build your new block entry
        b = {"id": ref_id, "type": blk["type"]}
        for k, v in blk.items():
            if k in ("id", "type"):
                continue

            # remap any string or list of strings that point at other old_ids
            if isinstance(v, str) and v in ref_map:
                b[k] = ref_map[v]
            elif (
                isinstance(v, list)
                and all(isinstance(x, str) and x in ref_map for x in v)
            ):
                b[k] = [ref_map[x] for x in v]
            else:
                b[k] = v

        delete_items.append(b)

    ref_map = {}
    for old_id, blk in block_schema.items():
        key = (blk["type"], blk.get("name"))
        if key in existing_by_type_name:
            # reuse this default
            ref_map[old_id] = existing_by_type_name[key]
        else:
            # create afresh
            ref_map[old_id] = f"${old_id}"

    # 5) turn block_schema → a single payload array, skipping any old_id that
    #    mapped to an existing ID (i.e. those defaults we’re reusing)
    payload = []
    for old_id, blk in block_schema.items():
        ref_id = ref_map[old_id]
        if not isinstance(ref_id, str) or not ref_id.startswith("$"):
            # we’re reusing an existing block → skip creation
            continue

        # build your new block entry
        b = {"id": ref_id, "type": blk["type"]}
        for k, v in blk.items():
            if k in ("id", "type"):
                continue

            # remap any string or list of strings that point at other old_ids
            if isinstance(v, str) and v in ref_map:
                b[k] = ref_map[v]
            elif (
                isinstance(v, list)
                and all(isinstance(x, str) and x in ref_map for x in v)
            ):
                b[k] = [ref_map[x] for x in v]
            else:
                b[k] = v

        payload.append(b)

    # 6) one atomic patch: create all our non‐default blocks in one go
    resp = branch.update(
        delete=delete_items,
        blocks=payload,
        include_response=True
    )

    print("✅ Created/updated:", resp["crud"]["blocks"])
    return branch
# usage
new_branch = clone_template_as_new_repo(
    api_key=API_KEY,
    workspace_id=WORKSPACE_ID,
    block_schema=agent_template_branch.data["blocks"],
    template_name="Clone"
)
# Out:
# ✅ Created/updated: ['NSghWfrUj9OyAK8OBAXa-', 'NSghYm2RqDibih0igHFc-', 'NSghaQGUD5XkZv-hq4TTV', 'NSghcbxRIX9eXogEB0li-', 'NSgheitRQ51bMoH_95sZk', 'NSghgp0ThH8gNv5Ady03k', 'NSghpotSFHj43o7HNUfo-', 'PLCZKQWpjfNLcRbLg65yw6', 'PS2RplQSj4BWmhzMmPjhcw', 'PS2RplQVhDb66QvJmsYCLW', 'PS2RplQXbXTTTvk39J6CTw', 'PS2RplQZb3WgRT4M5GdMxL', 'PS2RplQcYr6NvVYKWhqzyr', 'PS2RplQfddhqtNpYBD8cYb', 'PS2RplQhbq9mV4CQYJ484g', 'PS2RplQkX5MLSMlQp2Yx9l', 'PS2RplQmYcz85mRZRnhsn4', 'PS2RplQpSdSzqNm3fC2ncl', 'PS2RplQrTgjfmtVf2R5jwV', 'PS2RplQtQkHnDQRmZfytDQ', 'PS2RplQwSsF2nJMYRQYqjl', 'PS2RplQyTpHCMHkTCtPrXh', 'PS2RplR2NgZCM8HJz8vfC8', 'PS2RplR4RkSYB57M7Rwrzj', 'PS2RplR6NGYpbWNWvsfz5g', 'PS2RplR8Mlg7t4RchpfCGP', 'PS2RplRBHpkr52zqmLq4Py', 'PS2RplRDKxzT3cz5mYhBT2', 'PS2RplRGKGyzHdcYdSvMdD', 'PS2RplRJKhvy2r29j9RzZg', 'PS2RplRLFKmXZBr2xy474m', 'PS2RplRNGKcBFCdJrPkzdP', 'PS2RplRQHZ8kRBTvyjZdMR', 'PS2RplRSCLhKBQhFQtHL6G', 'PS2RplRVF7NL3RWQlL79sw', 'PS2RplRXBH8vBwbkxK8BSw', 'PS2RplRZ8m9X7MxYjppGvG', 'PS2RplRc5vNmd8SfqM8tt7', 'PS2RplRf8rKBtGxCpRp8Vk', 'PS2RplRh6whf5P486RhkDH', 'PS2RplRk46vVdbNPcvMmd3', 'PS2RplRm3bxQRSWmy8K2Lx', 'PS2RplRp3BbjGk9tf95v2n', 'PS2RplRr2JgpxWMHtVKbJH', 'PS2RplRt2g9kmQzHmknwHF', 'PS2RplRvvm2Cm9tXnLfWJf', 'PS2RplRxzBk6BTZbbCXN6W', 'PS2RplRzzBrQbxt2sqL5r2', 'PS2RplS3t8SQ9BcfP7lVGH', 'PS2RplS5wmfGRv6W6hMLYf', 'PS2RplS7sGZ9DcFbM5SKbh', 'PS2RplS9pwKYFJWxw4tfzR', 'PS2RplSCpf5QwxymtvbzSX']

# %%
## future plan
# figure out how to prompt schema to drop all the keys and things we can change
# sysMl to schema round trip
